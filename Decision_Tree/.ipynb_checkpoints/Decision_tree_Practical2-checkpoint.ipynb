# %%
import pandas as pd 
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree 
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.metrics import accuracy_score , confusion_matrix , roc_auc_score , roc_curve
from pandas_profiling import ProfileReport

# %%
df = pd.read_csv('winequality_red.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
set(df.quality)
# Out:
# {3, 4, 5, 6, 7, 8}

# %%
ProfileReport(df)
# Out:
# Tab(children=(HTML(value='<div id="overview-content" class="row variable spacing">\n    <div class="row">\n   …
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %%
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
x = df.drop(columns='quality')

# %%
x
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1594     10.5
# 1595     11.2
# 1596     11.0
# 1597     10.2
# 1598     11.0
#
# [1599 rows x 11 columns]

# %%
y = df.quality

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
x_train , x_test, y_train,y_test = train_test_split(x,y,test_size = .25,random_state = 30)

# %%
x_train
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 1178            5.6             0.915         0.00             2.1      0.041
# 1189            8.8             0.955         0.05             1.8      0.075
# 161             7.6             0.680         0.02             1.3      0.072
# 109             8.1             0.785         0.52             2.0      0.122
# 961             7.1             0.560         0.14             1.6      0.078
# ...             ...               ...          ...             ...        ...
# 919             8.4             0.620         0.12             1.8      0.072
# 1164            9.0             0.785         0.24             1.7      0.078
# 500             7.8             0.520         0.25             1.9      0.081
# 941             9.9             0.270         0.49             5.0      0.082
# 421             6.6             0.840         0.03             2.3      0.059
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 1178                 17.0                  78.0  0.99346  3.68       0.73
# 1189                  5.0                  19.0  0.99616  3.30       0.44
# 161                   9.0                  20.0  0.99650  3.17       1.08
# 109                  37.0                 153.0  0.99690  3.21       0.69
# 961                   7.0                  18.0  0.99592  3.27       0.62
# ...                   ...                   ...      ...   ...        ...
# 919                  38.0                  46.0  0.99504  3.38       0.89
# 1164                 10.0                  21.0  0.99692  3.29       0.67
# 500                  14.0                  38.0  0.99840  3.43       0.65
# 941                   9.0                  17.0  0.99484  3.19       0.52
# 421                  32.0                  48.0  0.99520  3.52       0.56
#
#       alcohol
# 1178     11.4
# 1189      9.6
# 161       9.2
# 109       9.3
# 961       9.3
# ...       ...
# 919      11.8
# 1164     10.0
# 500       9.0
# 941      12.5
# 421      12.3
#
# [1199 rows x 11 columns]

# %%
x_test
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 1147           10.0             0.410         0.45            6.20      0.071
# 659             7.1             0.840         0.02            4.40      0.096
# 871             6.9             0.560         0.03            1.50      0.086
# 1333            9.1             0.775         0.22            2.20      0.079
# 1411            6.4             0.470         0.40            2.40      0.071
# ...             ...               ...          ...             ...        ...
# 721             8.9             0.480         0.24            2.85      0.094
# 490             9.3             0.775         0.27            2.80      0.078
# 575            12.3             0.270         0.49            3.10      0.079
# 1051            8.5             0.460         0.59            1.40      0.414
# 1212            6.8             0.650         0.02            2.10      0.078
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 1147                  6.0                  14.0  0.99702  3.21       0.49
# 659                   5.0                  13.0  0.99700  3.41       0.57
# 871                  36.0                  46.0  0.99522  3.53       0.57
# 1333                 12.0                  48.0  0.99760  3.18       0.51
# 1411                  8.0                  19.0  0.99630  3.56       0.73
# ...                   ...                   ...      ...   ...        ...
# 721                  35.0                 106.0  0.99820  3.10       0.53
# 490                  24.0                  56.0  0.99840  3.31       0.67
# 575                  28.0                  46.0  0.99930  3.20       0.80
# 1051                 16.0                  45.0  0.99702  3.03       1.34
# 1212                  8.0                  15.0  0.99498  3.35       0.62
#
#       alcohol
# 1147     11.8
# 659      11.0
# 871      10.6
# 1333      9.6
# 1411     10.6
# ...       ...
# 721       9.2
# 490      10.6
# 575      10.2
# 1051      9.2
# 1212     10.4
#
# [400 rows x 11 columns]

# %%
dt_model = DecisionTreeClassifier()

# %%
dt_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
import sklearn
import  matplotlib.pyplot as plt
from sklearn import tree
# %matplotlib inline

# %%
sklearn.__version__
# Out:
# '0.22.1'

# %%
plt.figure(figsize=(20,20))
tree.plot_tree(dt_model,filled=True)
# Out:
# [Text(609.9589346868884, 1057.0, 'X[10] <= 10.35\ngini = 0.642\nsamples = 1199\nvalue = [8, 35, 512, 477, 153, 14]'),
#  Text(356.39952299412914, 996.6, 'X[6] <= 95.5\ngini = 0.528\nsamples = 666\nvalue = [6, 20, 406, 209, 23, 2]'),
#  Text(221.89493639921722, 936.2, 'X[9] <= 0.585\ngini = 0.554\nsamples = 584\nvalue = [6, 19, 332, 202, 23, 2]'),
#  Text(81.54182974559687, 875.8, 'X[6] <= 90.5\ngini = 0.468\nsamples = 261\nvalue = [3, 14, 179, 63, 2, 0]'),
#  Text(56.94960861056751, 815.4000000000001, 'X[10] <= 9.075\ngini = 0.453\nsamples = 250\nvalue = [3, 14, 176, 55, 2, 0]'),
#  Text(19.412915851272015, 755.0, 'X[6] <= 39.0\ngini = 0.604\nsamples = 15\nvalue = [0, 2, 6, 7, 0, 0]'),
#  Text(11.647749510763209, 694.6, 'X[9] <= 0.54\ngini = 0.406\nsamples = 8\nvalue = [0, 1, 1, 6, 0, 0]'),
#  Text(7.765166340508806, 634.2, 'X[9] <= 0.48\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(3.882583170254403, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(11.647749510763209, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(15.530332681017612, 634.2, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(27.17808219178082, 694.6, 'X[9] <= 0.485\ngini = 0.449\nsamples = 7\nvalue = [0, 1, 5, 1, 0, 0]'),
#  Text(23.295499021526417, 634.2, 'X[2] <= 0.205\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(19.412915851272015, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(27.17808219178082, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(31.060665362035223, 634.2, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(94.48630136986301, 755.0, 'X[10] <= 9.85\ngini = 0.432\nsamples = 235\nvalue = [3, 12, 170, 48, 2, 0]'),
#  Text(64.00195694716243, 694.6, 'X[4] <= 0.08\ngini = 0.384\nsamples = 176\nvalue = [2, 11, 135, 27, 1, 0]'),
#  Text(46.71232876712328, 634.2, 'X[0] <= 10.05\ngini = 0.497\nsamples = 83\nvalue = [1, 6, 55, 20, 1, 0]'),
#  Text(34.94324853228963, 573.8, 'X[1] <= 0.42\ngini = 0.456\nsamples = 79\nvalue = [1, 3, 55, 19, 1, 0]'),
#  Text(23.052837573385517, 513.4, 'X[9] <= 0.555\ngini = 0.469\nsamples = 8\nvalue = [0, 0, 3, 5, 0, 0]'),
#  Text(19.170254403131114, 453.0, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(26.93542074363992, 453.0, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(46.833659491193735, 513.4, 'X[1] <= 0.862\ngini = 0.423\nsamples = 71\nvalue = [1, 3, 52, 14, 1, 0]'),
#  Text(34.70058708414873, 453.0, 'X[0] <= 7.65\ngini = 0.376\nsamples = 67\nvalue = [0, 1, 51, 14, 1, 0]'),
#  Text(22.082191780821915, 392.6, 'X[7] <= 0.999\ngini = 0.208\nsamples = 34\nvalue = [0, 0, 30, 4, 0, 0]'),
#  Text(18.199608610567513, 332.19999999999993, 'X[8] <= 3.565\ngini = 0.165\nsamples = 33\nvalue = [0, 0, 30, 3, 0, 0]'),
#  Text(14.317025440313111, 271.79999999999995, 'X[1] <= 0.515\ngini = 0.117\nsamples = 32\nvalue = [0, 0, 30, 2, 0, 0]'),
#  Text(10.434442270058709, 211.39999999999998, 'X[3] <= 1.95\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 4, 2, 0, 0]'),
#  Text(6.551859099804305, 151.0, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(14.317025440313111, 151.0, 'X[6] <= 35.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(10.434442270058709, 90.59999999999991, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(18.199608610567513, 90.59999999999991, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(18.199608610567513, 211.39999999999998, 'gini = 0.0\nsamples = 26\nvalue = [0, 0, 26, 0, 0, 0]'),
#  Text(22.082191780821915, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(25.96477495107632, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(47.318982387475536, 392.6, 'X[6] <= 79.0\ngini = 0.501\nsamples = 33\nvalue = [0, 1, 21, 10, 1, 0]'),
#  Text(43.43639921722113, 332.19999999999993, 'X[2] <= 0.195\ngini = 0.453\nsamples = 30\nvalue = [0, 1, 21, 7, 1, 0]'),
#  Text(33.72994129158513, 271.79999999999995, 'X[2] <= 0.05\ngini = 0.639\nsamples = 12\nvalue = [0, 1, 5, 5, 1, 0]'),
#  Text(25.96477495107632, 211.39999999999998, 'X[7] <= 0.997\ngini = 0.5\nsamples = 6\nvalue = [0, 1, 4, 0, 1, 0]'),
#  Text(22.082191780821915, 151.0, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(29.84735812133072, 151.0, 'X[6] <= 16.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1, 0]'),
#  Text(25.96477495107632, 90.59999999999991, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(33.72994129158513, 90.59999999999991, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(41.495107632093934, 211.39999999999998, 'X[9] <= 0.46\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 5, 0, 0]'),
#  Text(37.61252446183953, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(45.37769080234833, 151.0, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(53.14285714285714, 271.79999999999995, 'X[1] <= 0.767\ngini = 0.198\nsamples = 18\nvalue = [0, 0, 16, 2, 0, 0]'),
#  Text(49.26027397260274, 211.39999999999998, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 16, 0, 0, 0]'),
#  Text(57.025440313111545, 211.39999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(51.201565557729936, 332.19999999999993, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(58.96673189823874, 453.0, 'X[3] <= 1.95\ngini = 0.625\nsamples = 4\nvalue = [1, 2, 1, 0, 0, 0]'),
#  Text(55.08414872798434, 392.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(62.84931506849315, 392.6, 'X[5] <= 12.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0, 0, 0]'),
#  Text(58.96673189823874, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(66.73189823874755, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(58.48140900195694, 573.8, 'X[10] <= 9.7\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 0, 1, 0, 0]'),
#  Text(54.59882583170254, 513.4, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(62.36399217221135, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(81.29158512720156, 634.2, 'X[8] <= 3.255\ngini = 0.251\nsamples = 93\nvalue = [1, 5, 80, 7, 0, 0]'),
#  Text(77.40900195694717, 573.8, 'gini = 0.0\nsamples = 42\nvalue = [0, 0, 42, 0, 0, 0]'),
#  Text(85.17416829745596, 573.8, 'X[1] <= 0.53\ngini = 0.416\nsamples = 51\nvalue = [1, 5, 38, 7, 0, 0]'),
#  Text(70.61448140900195, 513.4, 'X[4] <= 0.089\ngini = 0.1\nsamples = 19\nvalue = [0, 0, 18, 1, 0, 0]'),
#  Text(66.73189823874755, 453.0, 'gini = 0.0\nsamples = 17\nvalue = [0, 0, 17, 0, 0, 0]'),
#  Text(74.49706457925636, 453.0, 'X[5] <= 13.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(70.61448140900195, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(78.37964774951075, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(99.73385518590997, 513.4, 'X[0] <= 8.95\ngini = 0.549\nsamples = 32\nvalue = [1, 5, 20, 6, 0, 0]'),
#  Text(95.85127201565557, 453.0, 'X[1] <= 0.647\ngini = 0.509\nsamples = 30\nvalue = [1, 5, 20, 4, 0, 0]'),
#  Text(86.14481409001957, 392.6, 'X[8] <= 3.365\ngini = 0.593\nsamples = 9\nvalue = [0, 1, 4, 4, 0, 0]'),
#  Text(82.26223091976516, 332.19999999999993, 'X[5] <= 12.5\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4, 0, 0, 0]'),
#  Text(78.37964774951075, 271.79999999999995, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(86.14481409001957, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(90.02739726027397, 332.19999999999993, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(105.55772994129158, 392.6, 'X[10] <= 9.55\ngini = 0.381\nsamples = 21\nvalue = [1, 4, 16, 0, 0, 0]'),
#  Text(97.79256360078277, 332.19999999999993, 'X[10] <= 9.25\ngini = 0.133\nsamples = 14\nvalue = [0, 1, 13, 0, 0, 0]'),
#  Text(93.90998043052836, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(101.67514677103718, 271.79999999999995, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0, 0]'),
#  Text(113.32289628180038, 332.19999999999993, 'X[1] <= 0.745\ngini = 0.612\nsamples = 7\nvalue = [1, 3, 3, 0, 0, 0]'),
#  Text(109.44031311154598, 271.79999999999995, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(117.20547945205479, 271.79999999999995, 'X[5] <= 14.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3, 0, 0, 0, 0]'),
#  Text(113.32289628180038, 211.39999999999998, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(121.0880626223092, 211.39999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(103.61643835616438, 453.0, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(124.97064579256359, 694.6, 'X[9] <= 0.485\ngini = 0.521\nsamples = 59\nvalue = [1, 1, 35, 21, 1, 0]'),
#  Text(113.32289628180038, 634.2, 'X[3] <= 1.3\ngini = 0.227\nsamples = 16\nvalue = [0, 0, 14, 1, 1, 0]'),
#  Text(109.44031311154598, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(117.20547945205479, 573.8, 'X[7] <= 0.998\ngini = 0.124\nsamples = 15\nvalue = [0, 0, 14, 1, 0, 0]'),
#  Text(113.32289628180038, 513.4, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0, 0, 0]'),
#  Text(121.0880626223092, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(136.6183953033268, 634.2, 'X[0] <= 6.95\ngini = 0.544\nsamples = 43\nvalue = [1, 1, 21, 20, 0, 0]'),
#  Text(132.7358121330724, 573.8, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(140.5009784735812, 573.8, 'X[4] <= 0.082\ngini = 0.544\nsamples = 38\nvalue = [1, 1, 16, 20, 0, 0]'),
#  Text(128.853228962818, 513.4, 'X[7] <= 0.996\ngini = 0.525\nsamples = 25\nvalue = [1, 0, 14, 10, 0, 0]'),
#  Text(124.97064579256359, 453.0, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(132.7358121330724, 453.0, 'X[8] <= 3.07\ngini = 0.543\nsamples = 19\nvalue = [1, 0, 8, 10, 0, 0]'),
#  Text(128.853228962818, 392.6, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(136.6183953033268, 392.6, 'X[5] <= 3.5\ngini = 0.508\nsamples = 16\nvalue = [1, 0, 5, 10, 0, 0]'),
#  Text(132.7358121330724, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(140.5009784735812, 332.19999999999993, 'X[3] <= 2.55\ngini = 0.444\nsamples = 15\nvalue = [0, 0, 5, 10, 0, 0]'),
#  Text(132.7358121330724, 271.79999999999995, 'X[2] <= 0.265\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 2, 8, 0, 0]'),
#  Text(128.853228962818, 211.39999999999998, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(136.6183953033268, 211.39999999999998, 'X[1] <= 0.38\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(132.7358121330724, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(140.5009784735812, 151.0, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(148.26614481409, 271.79999999999995, 'X[2] <= 0.295\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(144.3835616438356, 211.39999999999998, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(152.14872798434442, 211.39999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(152.14872798434442, 513.4, 'X[2] <= 0.305\ngini = 0.379\nsamples = 13\nvalue = [0, 1, 2, 10, 0, 0]'),
#  Text(148.26614481409, 453.0, 'X[6] <= 16.0\ngini = 0.165\nsamples = 11\nvalue = [0, 1, 0, 10, 0, 0]'),
#  Text(144.3835616438356, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(152.14872798434442, 392.6, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(156.03131115459882, 453.0, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(106.13405088062622, 815.4000000000001, 'X[4] <= 0.083\ngini = 0.397\nsamples = 11\nvalue = [0, 0, 3, 8, 0, 0]'),
#  Text(102.25146771037181, 755.0, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(110.01663405088063, 755.0, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(362.24804305283755, 875.8, 'X[1] <= 0.555\ngini = 0.586\nsamples = 323\nvalue = [3, 5, 153, 139, 21, 2]'),
#  Text(299.7172211350293, 815.4000000000001, 'X[4] <= 0.098\ngini = 0.59\nsamples = 176\nvalue = [1, 1, 61, 93, 18, 2]'),
#  Text(247.33268101761252, 755.0, 'X[9] <= 0.645\ngini = 0.566\nsamples = 137\nvalue = [0, 0, 38, 80, 17, 2]'),
#  Text(187.57729941291583, 694.6, 'X[3] <= 1.95\ngini = 0.548\nsamples = 56\nvalue = [0, 0, 28, 25, 3, 0]'),
#  Text(167.67906066536202, 634.2, 'X[1] <= 0.385\ngini = 0.461\nsamples = 16\nvalue = [0, 0, 4, 11, 1, 0]'),
#  Text(163.7964774951076, 573.8, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(171.56164383561642, 573.8, 'X[1] <= 0.525\ngini = 0.58\nsamples = 10\nvalue = [0, 0, 4, 5, 1, 0]'),
#  Text(167.67906066536202, 513.4, 'X[0] <= 7.55\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 4, 1, 1, 0]'),
#  Text(163.7964774951076, 453.0, 'X[7] <= 0.997\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(159.91389432485323, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(167.67906066536202, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(171.56164383561642, 453.0, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(175.44422700587083, 513.4, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(207.47553816046965, 634.2, 'X[5] <= 14.0\ngini = 0.515\nsamples = 40\nvalue = [0, 0, 24, 14, 2, 0]'),
#  Text(187.09197651663405, 573.8, 'X[5] <= 5.5\ngini = 0.571\nsamples = 14\nvalue = [0, 0, 4, 8, 2, 0]'),
#  Text(183.20939334637964, 513.4, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(190.97455968688845, 513.4, 'X[10] <= 9.45\ngini = 0.43\nsamples = 11\nvalue = [0, 0, 1, 8, 2, 0]'),
#  Text(187.09197651663405, 453.0, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(194.85714285714283, 453.0, 'X[5] <= 8.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]'),
#  Text(190.97455968688845, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(198.73972602739724, 392.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(227.85909980430526, 573.8, 'X[6] <= 82.0\ngini = 0.355\nsamples = 26\nvalue = [0, 0, 20, 6, 0, 0]'),
#  Text(218.15264187866927, 513.4, 'X[1] <= 0.545\ngini = 0.287\nsamples = 23\nvalue = [0, 0, 19, 4, 0, 0]'),
#  Text(210.38747553816046, 453.0, 'X[3] <= 6.7\ngini = 0.18\nsamples = 20\nvalue = [0, 0, 18, 2, 0, 0]'),
#  Text(206.50489236790605, 392.6, 'X[4] <= 0.084\ngini = 0.1\nsamples = 19\nvalue = [0, 0, 18, 1, 0, 0]'),
#  Text(202.62230919765165, 332.19999999999993, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 16, 0, 0, 0]'),
#  Text(210.38747553816046, 332.19999999999993, 'X[7] <= 0.997\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(206.50489236790605, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(214.27005870841487, 271.79999999999995, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(214.27005870841487, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(225.91780821917806, 453.0, 'X[5] <= 19.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(222.03522504892368, 392.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(229.80039138943246, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(237.56555772994128, 513.4, 'X[1] <= 0.515\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(233.68297455968687, 453.0, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(241.44814090019568, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(307.08806262230917, 694.6, 'X[4] <= 0.094\ngini = 0.493\nsamples = 81\nvalue = [0, 0, 10, 55, 14, 2]'),
#  Text(291.1937377690802, 634.2, 'X[3] <= 2.35\ngini = 0.459\nsamples = 76\nvalue = [0, 0, 9, 54, 11, 2]'),
#  Text(278.8180039138943, 573.8, 'X[0] <= 11.7\ngini = 0.555\nsamples = 55\nvalue = [0, 0, 8, 34, 11, 2]'),
#  Text(265.7142857142857, 513.4, 'X[6] <= 48.5\ngini = 0.468\nsamples = 47\nvalue = [0, 0, 6, 33, 7, 1]'),
#  Text(251.1545988258317, 453.0, 'X[7] <= 0.997\ngini = 0.359\nsamples = 38\nvalue = [0, 0, 3, 30, 4, 1]'),
#  Text(237.56555772994128, 392.6, 'X[5] <= 15.5\ngini = 0.542\nsamples = 12\nvalue = [0, 0, 0, 7, 4, 1]'),
#  Text(233.68297455968687, 332.19999999999993, 'X[2] <= 0.305\ngini = 0.571\nsamples = 7\nvalue = [0, 0, 0, 2, 4, 1]'),
#  Text(229.80039138943246, 271.79999999999995, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(237.56555772994128, 271.79999999999995, 'X[5] <= 10.0\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 0, 2, 1, 1]'),
#  Text(233.68297455968687, 211.39999999999998, 'X[10] <= 10.15\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(229.80039138943246, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(237.56555772994128, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(241.44814090019568, 211.39999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(241.44814090019568, 332.19999999999993, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(264.7436399217221, 392.6, 'X[7] <= 0.999\ngini = 0.204\nsamples = 26\nvalue = [0, 0, 3, 23, 0, 0]'),
#  Text(260.8610567514677, 332.19999999999993, 'X[3] <= 2.15\ngini = 0.147\nsamples = 25\nvalue = [0, 0, 2, 23, 0, 0]'),
#  Text(253.0958904109589, 271.79999999999995, 'X[4] <= 0.087\ngini = 0.087\nsamples = 22\nvalue = [0, 0, 1, 21, 0, 0]'),
#  Text(249.2133072407045, 211.39999999999998, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 0, 19, 0, 0]'),
#  Text(256.9784735812133, 211.39999999999998, 'X[9] <= 0.675\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(253.0958904109589, 151.0, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(260.8610567514677, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(268.6262230919765, 271.79999999999995, 'X[0] <= 9.7\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(264.7436399217221, 211.39999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(272.5088062622309, 211.39999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(268.6262230919765, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(280.2739726027397, 453.0, 'X[5] <= 24.0\ngini = 0.667\nsamples = 9\nvalue = [0, 0, 3, 3, 3, 0]'),
#  Text(276.3913894324853, 392.6, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(284.1565557729941, 392.6, 'X[1] <= 0.44\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 0, 3, 3, 0]'),
#  Text(280.2739726027397, 332.19999999999993, 'X[3] <= 1.95\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(276.3913894324853, 271.79999999999995, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(284.1565557729941, 271.79999999999995, 'X[4] <= 0.066\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(280.2739726027397, 211.39999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(288.03913894324853, 211.39999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(288.03913894324853, 332.19999999999993, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(291.92172211350294, 513.4, 'X[1] <= 0.295\ngini = 0.656\nsamples = 8\nvalue = [0, 0, 2, 1, 4, 1]'),
#  Text(288.03913894324853, 453.0, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(295.80430528375734, 453.0, 'X[7] <= 0.999\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 0, 1]'),
#  Text(291.92172211350294, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(299.68688845401175, 392.6, 'X[5] <= 20.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(295.80430528375734, 332.19999999999993, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(303.5694716242661, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(303.5694716242661, 573.8, 'X[9] <= 0.665\ngini = 0.091\nsamples = 21\nvalue = [0, 0, 1, 20, 0, 0]'),
#  Text(299.68688845401175, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(307.4520547945205, 513.4, 'gini = 0.0\nsamples = 20\nvalue = [0, 0, 0, 20, 0, 0]'),
#  Text(322.98238747553813, 634.2, 'X[9] <= 0.69\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 1, 1, 3, 0]'),
#  Text(319.0998043052837, 573.8, 'X[7] <= 0.998\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(315.2172211350293, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(322.98238747553813, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(326.86497064579254, 573.8, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(352.1017612524462, 755.0, 'X[5] <= 6.5\ngini = 0.539\nsamples = 39\nvalue = [1, 1, 23, 13, 1, 0]'),
#  Text(342.39530332681016, 694.6, 'X[6] <= 20.0\ngini = 0.521\nsamples = 13\nvalue = [0, 0, 4, 8, 1, 0]'),
#  Text(338.51272015655576, 634.2, 'X[5] <= 5.5\ngini = 0.594\nsamples = 8\nvalue = [0, 0, 4, 3, 1, 0]'),
#  Text(334.63013698630135, 573.8, 'X[2] <= 0.61\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 0, 1, 0]'),
#  Text(330.74755381604695, 513.4, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(338.51272015655576, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(342.39530332681016, 573.8, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(346.27788649706457, 634.2, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(361.8082191780822, 694.6, 'X[5] <= 30.0\ngini = 0.426\nsamples = 26\nvalue = [1, 1, 19, 5, 0, 0]'),
#  Text(354.0430528375734, 634.2, 'X[10] <= 9.25\ngini = 0.172\nsamples = 21\nvalue = [0, 0, 19, 2, 0, 0]'),
#  Text(350.160469667319, 573.8, 'X[6] <= 59.0\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(346.27788649706457, 513.4, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(354.0430528375734, 513.4, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(357.9256360078278, 573.8, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 16, 0, 0, 0]'),
#  Text(369.57338551859095, 634.2, 'X[0] <= 10.3\ngini = 0.56\nsamples = 5\nvalue = [1, 1, 0, 3, 0, 0]'),
#  Text(365.69080234833655, 573.8, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(373.45596868884536, 573.8, 'X[0] <= 11.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0, 0]'),
#  Text(369.57338551859095, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(377.33855185909977, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(424.77886497064577, 815.4000000000001, 'X[3] <= 1.95\ngini = 0.509\nsamples = 147\nvalue = [2, 4, 92, 46, 3, 0]'),
#  Text(394.8101761252446, 755.0, 'X[10] <= 9.85\ngini = 0.388\nsamples = 54\nvalue = [1, 2, 41, 10, 0, 0]'),
#  Text(381.2211350293542, 694.6, 'X[5] <= 3.5\ngini = 0.224\nsamples = 40\nvalue = [0, 1, 35, 4, 0, 0]'),
#  Text(377.33855185909977, 634.2, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(385.1037181996086, 634.2, 'X[3] <= 1.4\ngini = 0.148\nsamples = 38\nvalue = [0, 1, 35, 2, 0, 0]'),
#  Text(381.2211350293542, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(388.986301369863, 573.8, 'X[2] <= 0.595\ngini = 0.102\nsamples = 37\nvalue = [0, 0, 35, 2, 0, 0]'),
#  Text(385.1037181996086, 513.4, 'X[5] <= 26.5\ngini = 0.054\nsamples = 36\nvalue = [0, 0, 35, 1, 0, 0]'),
#  Text(381.2211350293542, 453.0, 'gini = 0.0\nsamples = 32\nvalue = [0, 0, 32, 0, 0, 0]'),
#  Text(388.986301369863, 453.0, 'X[1] <= 0.605\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(385.1037181996086, 392.6, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(392.8688845401174, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(392.8688845401174, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(408.399217221135, 694.6, 'X[1] <= 0.683\ngini = 0.622\nsamples = 14\nvalue = [1, 1, 6, 6, 0, 0]'),
#  Text(400.6340508806262, 634.2, 'X[9] <= 0.625\ngini = 0.245\nsamples = 7\nvalue = [0, 1, 0, 6, 0, 0]'),
#  Text(396.7514677103718, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(404.5166340508806, 573.8, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(416.16438356164383, 634.2, 'X[5] <= 8.0\ngini = 0.245\nsamples = 7\nvalue = [1, 0, 6, 0, 0, 0]'),
#  Text(412.2818003913894, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(420.04696673189824, 573.8, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(454.74755381604695, 755.0, 'X[6] <= 82.5\ngini = 0.548\nsamples = 93\nvalue = [1, 2, 51, 36, 3, 0]'),
#  Text(450.86497064579254, 694.6, 'X[0] <= 6.85\ngini = 0.564\nsamples = 84\nvalue = [1, 2, 42, 36, 3, 0]'),
#  Text(431.6947162426614, 634.2, 'X[6] <= 17.5\ngini = 0.245\nsamples = 7\nvalue = [0, 1, 6, 0, 0, 0]'),
#  Text(427.812133072407, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(435.5772994129158, 573.8, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(470.0352250489237, 634.2, 'X[7] <= 0.997\ngini = 0.561\nsamples = 77\nvalue = [1, 1, 36, 36, 3, 0]'),
#  Text(443.3424657534246, 573.8, 'X[1] <= 0.84\ngini = 0.446\nsamples = 11\nvalue = [0, 1, 1, 8, 1, 0]'),
#  Text(435.5772994129158, 513.4, 'X[4] <= 0.074\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 1, 8, 0, 0]'),
#  Text(431.6947162426614, 453.0, 'X[9] <= 0.605\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(427.812133072407, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(435.5772994129158, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(439.4598825831702, 453.0, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(451.10763209393343, 513.4, 'X[1] <= 0.945\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1, 0]'),
#  Text(447.225048923679, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(454.99021526418784, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(496.7279843444227, 573.8, 'X[2] <= 0.26\ngini = 0.538\nsamples = 66\nvalue = [1, 0, 35, 28, 2, 0]'),
#  Text(476.3444227005871, 513.4, 'X[8] <= 3.275\ngini = 0.486\nsamples = 50\nvalue = [0, 0, 31, 18, 1, 0]'),
#  Text(462.75538160469665, 453.0, 'X[1] <= 0.725\ngini = 0.133\nsamples = 14\nvalue = [0, 0, 13, 1, 0, 0]'),
#  Text(458.87279843444225, 392.6, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(466.63796477495106, 392.6, 'X[1] <= 0.748\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(462.75538160469665, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(470.52054794520546, 332.19999999999993, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(489.93346379647744, 453.0, 'X[10] <= 9.55\ngini = 0.526\nsamples = 36\nvalue = [0, 0, 18, 17, 1, 0]'),
#  Text(482.1682974559687, 392.6, 'X[9] <= 0.645\ngini = 0.337\nsamples = 14\nvalue = [0, 0, 3, 11, 0, 0]'),
#  Text(478.2857142857143, 332.19999999999993, 'X[10] <= 9.25\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 3, 0, 0]'),
#  Text(474.40313111545987, 271.79999999999995, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(482.1682974559687, 271.79999999999995, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(486.0508806262231, 332.19999999999993, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(497.69863013698625, 392.6, 'X[8] <= 3.29\ngini = 0.459\nsamples = 22\nvalue = [0, 0, 15, 6, 1, 0]'),
#  Text(493.81604696673185, 332.19999999999993, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(501.58121330724066, 332.19999999999993, 'X[7] <= 0.997\ngini = 0.395\nsamples = 20\nvalue = [0, 0, 15, 4, 1, 0]'),
#  Text(497.69863013698625, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(505.46379647749507, 271.79999999999995, 'X[9] <= 0.88\ngini = 0.332\nsamples = 19\nvalue = [0, 0, 15, 4, 0, 0]'),
#  Text(497.69863013698625, 211.39999999999998, 'X[7] <= 0.997\ngini = 0.219\nsamples = 16\nvalue = [0, 0, 14, 2, 0, 0]'),
#  Text(493.81604696673185, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(501.58121330724066, 151.0, 'X[9] <= 0.745\ngini = 0.124\nsamples = 15\nvalue = [0, 0, 14, 1, 0, 0]'),
#  Text(497.69863013698625, 90.59999999999991, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]'),
#  Text(505.46379647749507, 90.59999999999991, 'X[8] <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(501.58121330724066, 30.200000000000045, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(509.3463796477495, 30.200000000000045, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(513.2289628180039, 211.39999999999998, 'X[2] <= 0.11\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(509.3463796477495, 151.0, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(517.1115459882583, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(517.1115459882583, 513.4, 'X[4] <= 0.078\ngini = 0.539\nsamples = 16\nvalue = [1, 0, 4, 10, 1, 0]'),
#  Text(513.2289628180039, 453.0, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(520.9941291585127, 453.0, 'X[8] <= 3.09\ngini = 0.391\nsamples = 13\nvalue = [1, 0, 1, 10, 1, 0]'),
#  Text(513.2289628180039, 392.6, 'X[8] <= 3.03\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(509.3463796477495, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(517.1115459882583, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(528.7592954990215, 392.6, 'X[4] <= 0.148\ngini = 0.165\nsamples = 11\nvalue = [1, 0, 0, 10, 0, 0]'),
#  Text(524.8767123287671, 332.19999999999993, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(532.6418786692759, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(458.63013698630135, 694.6, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(490.90410958904107, 936.2, 'X[8] <= 2.935\ngini = 0.178\nsamples = 82\nvalue = [0, 1, 74, 7, 0, 0]'),
#  Text(481.19765166340505, 875.8, 'X[10] <= 9.85\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(477.31506849315065, 815.4000000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(485.08023483365946, 815.4000000000001, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(500.6105675146771, 875.8, 'X[3] <= 1.55\ngini = 0.121\nsamples = 78\nvalue = [0, 1, 73, 4, 0, 0]'),
#  Text(492.8454011741683, 815.4000000000001, 'X[1] <= 0.468\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(488.96281800391387, 755.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(496.7279843444227, 755.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(508.3757338551859, 815.4000000000001, 'X[6] <= 109.5\ngini = 0.1\nsamples = 76\nvalue = [0, 0, 72, 4, 0, 0]'),
#  Text(504.4931506849315, 755.0, 'X[8] <= 3.175\ngini = 0.252\nsamples = 27\nvalue = [0, 0, 23, 4, 0, 0]'),
#  Text(496.7279843444227, 694.6, 'X[0] <= 8.05\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(492.8454011741683, 634.2, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(500.6105675146771, 634.2, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(512.2583170254403, 694.6, 'X[1] <= 0.545\ngini = 0.165\nsamples = 22\nvalue = [0, 0, 20, 2, 0, 0]'),
#  Text(508.3757338551859, 634.2, 'X[5] <= 20.0\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 4, 2, 0, 0]'),
#  Text(504.4931506849315, 573.8, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(512.2583170254403, 573.8, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(516.1409001956947, 634.2, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 16, 0, 0, 0]'),
#  Text(512.2583170254403, 755.0, 'gini = 0.0\nsamples = 49\nvalue = [0, 0, 49, 0, 0, 0]'),
#  Text(863.5183463796477, 996.6, 'X[10] <= 11.55\ngini = 0.647\nsamples = 533\nvalue = [2, 15, 106, 268, 130, 12]'),
#  Text(697.4241682974559, 936.2, 'X[1] <= 0.405\ngini = 0.629\nsamples = 356\nvalue = [2, 13, 96, 186, 55, 4]'),
#  Text(612.2348336594912, 875.8, 'X[9] <= 0.735\ngini = 0.653\nsamples = 118\nvalue = [0, 1, 20, 53, 40, 4]'),
#  Text(560.3052837573385, 815.4000000000001, 'X[1] <= 0.287\ngini = 0.627\nsamples = 61\nvalue = [0, 1, 13, 33, 11, 3]'),
#  Text(535.5538160469667, 755.0, 'X[4] <= 0.075\ngini = 0.64\nsamples = 15\nvalue = [0, 0, 7, 4, 4, 0]'),
#  Text(527.7886497064579, 694.6, 'X[9] <= 0.68\ngini = 0.594\nsamples = 8\nvalue = [0, 0, 1, 3, 4, 0]'),
#  Text(523.9060665362035, 634.2, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(531.6712328767123, 634.2, 'X[5] <= 12.0\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(527.7886497064579, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(535.5538160469667, 573.8, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(543.3189823874756, 694.6, 'X[6] <= 13.5\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 6, 1, 0, 0]'),
#  Text(539.4363992172212, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(547.20156555773, 634.2, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(585.0567514677103, 755.0, 'X[8] <= 3.285\ngini = 0.558\nsamples = 46\nvalue = [0, 1, 6, 29, 7, 3]'),
#  Text(564.6731898238747, 694.6, 'X[8] <= 3.145\ngini = 0.656\nsamples = 28\nvalue = [0, 0, 4, 14, 7, 3]'),
#  Text(554.9667318982387, 634.2, 'X[4] <= 0.097\ngini = 0.292\nsamples = 12\nvalue = [0, 0, 1, 10, 1, 0]'),
#  Text(551.0841487279844, 573.8, 'X[9] <= 0.715\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 0, 10, 1, 0]'),
#  Text(547.20156555773, 513.4, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(554.9667318982387, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(558.8493150684931, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(574.3796477495107, 634.2, 'X[7] <= 0.995\ngini = 0.727\nsamples = 16\nvalue = [0, 0, 3, 4, 6, 3]'),
#  Text(566.6144814090019, 573.8, 'X[5] <= 16.0\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 0, 4, 1]'),
#  Text(562.7318982387475, 513.4, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(570.4970645792563, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(582.1448140900195, 573.8, 'X[9] <= 0.66\ngini = 0.727\nsamples = 11\nvalue = [0, 0, 3, 4, 2, 2]'),
#  Text(578.2622309197651, 513.4, 'X[9] <= 0.605\ngini = 0.719\nsamples = 8\nvalue = [0, 0, 3, 1, 2, 2]'),
#  Text(570.4970645792563, 453.0, 'X[1] <= 0.335\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(566.6144814090019, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(574.3796477495107, 392.6, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(586.0273972602739, 453.0, 'X[4] <= 0.078\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 0, 0, 2, 2]'),
#  Text(582.1448140900195, 392.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(589.9099804305283, 392.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(586.0273972602739, 513.4, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(605.440313111546, 694.6, 'X[6] <= 102.5\ngini = 0.29\nsamples = 18\nvalue = [0, 1, 2, 15, 0, 0]'),
#  Text(601.5577299412915, 634.2, 'X[10] <= 10.8\ngini = 0.208\nsamples = 17\nvalue = [0, 0, 2, 15, 0, 0]'),
#  Text(597.6751467710371, 573.8, 'X[6] <= 27.5\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(593.7925636007827, 513.4, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(601.5577299412915, 513.4, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(605.440313111546, 573.8, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 13, 0, 0]'),
#  Text(609.3228962818004, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(664.1643835616438, 815.4000000000001, 'X[6] <= 104.5\ngini = 0.603\nsamples = 57\nvalue = [0, 0, 7, 20, 29, 1]'),
#  Text(660.2818003913894, 755.0, 'X[7] <= 0.998\ngini = 0.569\nsamples = 54\nvalue = [0, 0, 4, 20, 29, 1]'),
#  Text(645.2367906066536, 694.6, 'X[8] <= 3.395\ngini = 0.623\nsamples = 33\nvalue = [0, 0, 4, 15, 13, 1]'),
#  Text(626.7945205479451, 634.2, 'X[4] <= 0.061\ngini = 0.58\nsamples = 24\nvalue = [0, 0, 3, 14, 6, 1]'),
#  Text(613.2054794520548, 573.8, 'X[3] <= 1.9\ngini = 0.667\nsamples = 6\nvalue = [0, 0, 1, 1, 3, 1]'),
#  Text(609.3228962818004, 513.4, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(617.0880626223092, 513.4, 'X[3] <= 2.1\ngini = 0.667\nsamples = 3\nvalue = [0, 0, 1, 1, 0, 1]'),
#  Text(613.2054794520548, 453.0, 'X[10] <= 11.1\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(609.3228962818004, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(617.0880626223092, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(620.9706457925636, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(640.3835616438356, 573.8, 'X[2] <= 0.535\ngini = 0.438\nsamples = 18\nvalue = [0, 0, 2, 13, 3, 0]'),
#  Text(632.6183953033268, 513.4, 'X[6] <= 20.5\ngini = 0.245\nsamples = 14\nvalue = [0, 0, 0, 12, 2, 0]'),
#  Text(628.7358121330724, 453.0, 'X[2] <= 0.425\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 0, 2, 2, 0]'),
#  Text(624.853228962818, 392.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(632.6183953033268, 392.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(636.5009784735812, 453.0, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(648.1487279843444, 513.4, 'X[1] <= 0.31\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 1, 0]'),
#  Text(644.26614481409, 453.0, 'X[3] <= 1.7\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(640.3835616438356, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(648.1487279843444, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(652.0313111545988, 453.0, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(663.679060665362, 634.2, 'X[10] <= 10.75\ngini = 0.37\nsamples = 9\nvalue = [0, 0, 1, 1, 7, 0]'),
#  Text(659.7964774951076, 573.8, 'X[4] <= 0.073\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(655.9138943248532, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(663.679060665362, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(667.5616438356165, 573.8, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(675.3268101761253, 694.6, 'X[10] <= 10.45\ngini = 0.363\nsamples = 21\nvalue = [0, 0, 0, 5, 16, 0]'),
#  Text(671.4442270058709, 634.2, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(679.2093933463796, 634.2, 'X[9] <= 1.055\ngini = 0.266\nsamples = 19\nvalue = [0, 0, 0, 3, 16, 0]'),
#  Text(675.3268101761253, 573.8, 'X[7] <= 1.0\ngini = 0.198\nsamples = 18\nvalue = [0, 0, 0, 2, 16, 0]'),
#  Text(671.4442270058709, 513.4, 'X[6] <= 21.5\ngini = 0.111\nsamples = 17\nvalue = [0, 0, 0, 1, 16, 0]'),
#  Text(667.5616438356165, 453.0, 'X[7] <= 0.998\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 3, 0]'),
#  Text(663.679060665362, 392.6, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(671.4442270058709, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(675.3268101761253, 453.0, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 0, 13, 0]'),
#  Text(679.2093933463796, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(683.091976516634, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(668.0469667318982, 755.0, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(782.6135029354207, 875.8, 'X[9] <= 0.525\ngini = 0.579\nsamples = 238\nvalue = [2, 12, 76, 133, 15, 0]'),
#  Text(716.0939334637965, 815.4000000000001, 'X[0] <= 6.85\ngini = 0.547\nsamples = 31\nvalue = [1, 3, 19, 8, 0, 0]'),
#  Text(706.3874755381604, 755.0, 'X[4] <= 0.141\ngini = 0.66\nsamples = 10\nvalue = [0, 3, 3, 4, 0, 0]'),
#  Text(702.504892367906, 694.6, 'X[9] <= 0.455\ngini = 0.594\nsamples = 8\nvalue = [0, 3, 1, 4, 0, 0]'),
#  Text(694.7397260273972, 634.2, 'X[0] <= 6.35\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(690.8571428571428, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(698.6223091976516, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(710.2700587084148, 634.2, 'X[10] <= 10.95\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 0, 4, 0, 0]'),
#  Text(706.3874755381604, 573.8, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(714.1526418786692, 573.8, 'X[0] <= 6.4\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 1, 0, 0]'),
#  Text(710.2700587084148, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(718.0352250489236, 513.4, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(710.2700587084148, 694.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(725.8003913894324, 755.0, 'X[2] <= 0.295\ngini = 0.381\nsamples = 21\nvalue = [1, 0, 16, 4, 0, 0]'),
#  Text(721.917808219178, 694.6, 'X[10] <= 10.45\ngini = 0.277\nsamples = 19\nvalue = [1, 0, 16, 2, 0, 0]'),
#  Text(718.0352250489236, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(725.8003913894324, 634.2, 'X[8] <= 3.47\ngini = 0.204\nsamples = 18\nvalue = [1, 0, 16, 1, 0, 0]'),
#  Text(721.917808219178, 573.8, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0, 0, 0]'),
#  Text(729.6829745596868, 573.8, 'X[3] <= 1.85\ngini = 0.625\nsamples = 4\nvalue = [1, 0, 2, 1, 0, 0]'),
#  Text(725.8003913894324, 513.4, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(733.5655577299412, 513.4, 'X[7] <= 0.997\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1, 0, 0]'),
#  Text(729.6829745596868, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(737.4481409001957, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(729.6829745596868, 694.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(849.133072407045, 815.4000000000001, 'X[5] <= 12.5\ngini = 0.552\nsamples = 207\nvalue = [1, 9, 57, 125, 15, 0]'),
#  Text(817.2837573385518, 755.0, 'X[4] <= 0.09\ngini = 0.65\nsamples = 90\nvalue = [1, 8, 32, 41, 8, 0]'),
#  Text(796.1722113502935, 694.6, 'X[8] <= 3.6\ngini = 0.591\nsamples = 66\nvalue = [0, 6, 19, 37, 4, 0]'),
#  Text(792.2896281800391, 634.2, 'X[6] <= 61.0\ngini = 0.572\nsamples = 62\nvalue = [0, 6, 15, 37, 4, 0]'),
#  Text(777.2446183953033, 573.8, 'X[9] <= 0.615\ngini = 0.548\nsamples = 57\nvalue = [0, 6, 11, 36, 4, 0]'),
#  Text(758.8023483365948, 513.4, 'X[4] <= 0.079\ngini = 0.699\nsamples = 23\nvalue = [0, 5, 7, 9, 2, 0]'),
#  Text(745.2133072407045, 453.0, 'X[10] <= 11.1\ngini = 0.667\nsamples = 15\nvalue = [0, 4, 7, 3, 1, 0]'),
#  Text(737.4481409001957, 392.6, 'X[4] <= 0.076\ngini = 0.691\nsamples = 9\nvalue = [0, 4, 2, 2, 1, 0]'),
#  Text(733.5655577299412, 332.19999999999993, 'X[10] <= 10.85\ngini = 0.571\nsamples = 7\nvalue = [0, 4, 0, 2, 1, 0]'),
#  Text(729.6829745596868, 271.79999999999995, 'X[7] <= 0.996\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 0, 2, 1, 0]'),
#  Text(725.8003913894324, 211.39999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(733.5655577299412, 211.39999999999998, 'X[4] <= 0.066\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1, 0]'),
#  Text(729.6829745596868, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(737.4481409001957, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(737.4481409001957, 271.79999999999995, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(741.3307240704501, 332.19999999999993, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(752.9784735812133, 392.6, 'X[3] <= 2.05\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(749.0958904109589, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(756.8610567514677, 332.19999999999993, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(772.3913894324853, 453.0, 'X[1] <= 0.873\ngini = 0.406\nsamples = 8\nvalue = [0, 1, 0, 6, 1, 0]'),
#  Text(768.5088062622309, 392.6, 'X[3] <= 1.9\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 6, 1, 0]'),
#  Text(764.6262230919765, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(772.3913894324853, 332.19999999999993, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(776.2739726027397, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(795.6868884540118, 513.4, 'X[0] <= 12.05\ngini = 0.351\nsamples = 34\nvalue = [0, 1, 4, 27, 2, 0]'),
#  Text(787.9217221135029, 453.0, 'X[1] <= 0.905\ngini = 0.287\nsamples = 31\nvalue = [0, 1, 2, 26, 2, 0]'),
#  Text(784.0391389432485, 392.6, 'X[0] <= 6.1\ngini = 0.24\nsamples = 30\nvalue = [0, 0, 2, 26, 2, 0]'),
#  Text(780.1565557729941, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(787.9217221135029, 332.19999999999993, 'X[1] <= 0.445\ngini = 0.19\nsamples = 29\nvalue = [0, 0, 1, 26, 2, 0]'),
#  Text(780.1565557729941, 271.79999999999995, 'X[7] <= 0.996\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 0, 2, 2, 0]'),
#  Text(776.2739726027397, 211.39999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(784.0391389432485, 211.39999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(795.6868884540118, 271.79999999999995, 'X[4] <= 0.086\ngini = 0.077\nsamples = 25\nvalue = [0, 0, 1, 24, 0, 0]'),
#  Text(791.8043052837573, 211.39999999999998, 'gini = 0.0\nsamples = 23\nvalue = [0, 0, 0, 23, 0, 0]'),
#  Text(799.5694716242662, 211.39999999999998, 'X[0] <= 8.25\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(795.6868884540118, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(803.4520547945204, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(791.8043052837573, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(803.4520547945204, 453.0, 'X[5] <= 6.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(799.5694716242662, 392.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(807.3346379647749, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(807.3346379647749, 573.8, 'X[5] <= 10.0\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(803.4520547945204, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(811.2172211350293, 513.4, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(800.054794520548, 634.2, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(838.3953033268101, 694.6, 'X[2] <= 0.65\ngini = 0.642\nsamples = 24\nvalue = [1, 2, 13, 4, 4, 0]'),
#  Text(834.5127201565557, 634.2, 'X[10] <= 11.25\ngini = 0.567\nsamples = 21\nvalue = [1, 2, 13, 4, 1, 0]'),
#  Text(830.6301369863013, 573.8, 'X[4] <= 0.205\ngini = 0.482\nsamples = 19\nvalue = [1, 0, 13, 4, 1, 0]'),
#  Text(826.7475538160469, 513.4, 'X[3] <= 4.225\ngini = 0.394\nsamples = 17\nvalue = [1, 0, 13, 2, 1, 0]'),
#  Text(818.9823874755381, 453.0, 'X[6] <= 9.5\ngini = 0.24\nsamples = 15\nvalue = [0, 0, 13, 1, 1, 0]'),
#  Text(815.0998043052837, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(822.8649706457925, 392.6, 'X[7] <= 0.995\ngini = 0.133\nsamples = 14\nvalue = [0, 0, 13, 0, 1, 0]'),
#  Text(818.9823874755381, 332.19999999999993, 'X[7] <= 0.995\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(815.0998043052837, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(822.8649706457925, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(826.7475538160469, 332.19999999999993, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]'),
#  Text(834.5127201565557, 453.0, 'X[5] <= 8.0\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1, 0, 0]'),
#  Text(830.6301369863013, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(838.3953033268101, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(834.5127201565557, 513.4, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(838.3953033268101, 573.8, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(842.2778864970645, 634.2, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(880.9823874755381, 755.0, 'X[3] <= 4.4\ngini = 0.435\nsamples = 117\nvalue = [0, 1, 25, 84, 7, 0]'),
#  Text(866.7866927592954, 694.6, 'X[4] <= 0.056\ngini = 0.404\nsamples = 111\nvalue = [0, 1, 20, 83, 7, 0]'),
#  Text(850.0430528375733, 634.2, 'X[2] <= 0.465\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(846.1604696673189, 573.8, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(853.9256360078277, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(883.5303326810175, 634.2, 'X[7] <= 0.996\ngini = 0.374\nsamples = 106\nvalue = [0, 1, 16, 82, 7, 0]'),
#  Text(861.6908023483365, 573.8, 'X[1] <= 0.425\ngini = 0.188\nsamples = 58\nvalue = [0, 0, 5, 52, 1, 0]'),
#  Text(851.9843444227006, 513.4, 'X[9] <= 0.685\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(848.1017612524462, 453.0, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(855.866927592955, 453.0, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(871.3972602739725, 513.4, 'X[9] <= 0.535\ngini = 0.139\nsamples = 54\nvalue = [0, 0, 3, 50, 1, 0]'),
#  Text(863.6320939334637, 453.0, 'X[10] <= 11.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(859.7495107632094, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(867.5146771037181, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(879.1624266144813, 453.0, 'X[10] <= 10.575\ngini = 0.11\nsamples = 52\nvalue = [0, 0, 2, 49, 1, 0]'),
#  Text(875.2798434442269, 392.6, 'X[7] <= 0.995\ngini = 0.357\nsamples = 14\nvalue = [0, 0, 2, 11, 1, 0]'),
#  Text(871.3972602739725, 332.19999999999993, 'X[3] <= 1.9\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 1, 0]'),
#  Text(867.5146771037181, 271.79999999999995, 'X[3] <= 1.75\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(863.6320939334637, 211.39999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(871.3972602739725, 211.39999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(875.2798434442269, 271.79999999999995, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(879.1624266144813, 332.19999999999993, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(883.0450097847357, 392.6, 'gini = 0.0\nsamples = 38\nvalue = [0, 0, 0, 38, 0, 0]'),
#  Text(905.3698630136986, 573.8, 'X[3] <= 1.95\ngini = 0.541\nsamples = 48\nvalue = [0, 1, 11, 30, 6, 0]'),
#  Text(890.8101761252445, 513.4, 'X[7] <= 0.997\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 0, 1, 0]'),
#  Text(886.9275929549901, 453.0, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(894.692759295499, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(919.9295499021526, 513.4, 'X[8] <= 3.335\ngini = 0.489\nsamples = 44\nvalue = [0, 1, 8, 30, 5, 0]'),
#  Text(902.4579256360078, 453.0, 'X[4] <= 0.097\ngini = 0.35\nsamples = 31\nvalue = [0, 0, 7, 24, 0, 0]'),
#  Text(890.8101761252445, 392.6, 'X[4] <= 0.062\ngini = 0.227\nsamples = 23\nvalue = [0, 0, 3, 20, 0, 0]'),
#  Text(886.9275929549901, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(894.692759295499, 332.19999999999993, 'X[1] <= 0.415\ngini = 0.165\nsamples = 22\nvalue = [0, 0, 2, 20, 0, 0]'),
#  Text(890.8101761252445, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(898.5753424657534, 271.79999999999995, 'X[0] <= 8.1\ngini = 0.091\nsamples = 21\nvalue = [0, 0, 1, 20, 0, 0]'),
#  Text(894.692759295499, 211.39999999999998, 'X[2] <= 0.34\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(890.8101761252445, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(898.5753424657534, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(902.4579256360078, 211.39999999999998, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 0, 19, 0, 0]'),
#  Text(914.105675146771, 392.6, 'X[2] <= 0.395\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 4, 4, 0, 0]'),
#  Text(910.2230919765166, 332.19999999999993, 'X[4] <= 0.117\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(906.3405088062622, 271.79999999999995, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(914.105675146771, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(917.9882583170254, 332.19999999999993, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(937.4011741682974, 453.0, 'X[9] <= 0.68\ngini = 0.627\nsamples = 13\nvalue = [0, 1, 1, 6, 5, 0]'),
#  Text(929.6360078277886, 392.6, 'X[5] <= 37.5\ngini = 0.449\nsamples = 7\nvalue = [0, 1, 1, 5, 0, 0]'),
#  Text(925.7534246575342, 332.19999999999993, 'X[1] <= 0.947\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 0, 5, 0, 0]'),
#  Text(921.8708414872798, 271.79999999999995, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(929.6360078277886, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(933.518590998043, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(945.1663405088062, 392.6, 'X[1] <= 0.69\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 1, 5, 0]'),
#  Text(941.2837573385518, 332.19999999999993, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(949.0489236790606, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(895.1780821917807, 694.6, 'X[8] <= 3.255\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(891.2954990215263, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(899.0606653620351, 634.2, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(1029.6125244618395, 936.2, 'X[9] <= 0.685\ngini = 0.6\nsamples = 177\nvalue = [0, 2, 10, 82, 75, 8]'),
#  Text(985.9334637964774, 875.8, 'X[6] <= 15.5\ngini = 0.537\nsamples = 95\nvalue = [0, 2, 8, 59, 25, 1]'),
#  Text(968.4618395303327, 815.4000000000001, 'X[9] <= 0.585\ngini = 0.531\nsamples = 25\nvalue = [0, 0, 2, 8, 15, 0]'),
#  Text(960.6966731898239, 755.0, 'X[7] <= 0.994\ngini = 0.56\nsamples = 10\nvalue = [0, 0, 2, 6, 2, 0]'),
#  Text(956.8140900195694, 694.6, 'X[3] <= 2.15\ngini = 0.667\nsamples = 6\nvalue = [0, 0, 2, 2, 2, 0]'),
#  Text(952.931506849315, 634.2, 'X[4] <= 0.065\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 0, 2, 2, 0]'),
#  Text(949.0489236790606, 573.8, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(956.8140900195694, 573.8, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(960.6966731898239, 634.2, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(964.5792563600783, 694.6, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(976.2270058708415, 755.0, 'X[6] <= 9.0\ngini = 0.231\nsamples = 15\nvalue = [0, 0, 0, 2, 13, 0]'),
#  Text(972.3444227005871, 694.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(980.1095890410959, 694.6, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 0, 13, 0]'),
#  Text(1003.4050880626222, 815.4000000000001, 'X[5] <= 31.5\ngini = 0.44\nsamples = 70\nvalue = [0, 2, 6, 51, 10, 1]'),
#  Text(991.757338551859, 755.0, 'X[0] <= 4.65\ngini = 0.381\nsamples = 62\nvalue = [0, 2, 6, 48, 6, 0]'),
#  Text(987.8747553816046, 694.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(995.6399217221134, 694.6, 'X[2] <= 0.725\ngini = 0.361\nsamples = 61\nvalue = [0, 1, 6, 48, 6, 0]'),
#  Text(991.757338551859, 634.2, 'X[6] <= 26.5\ngini = 0.343\nsamples = 60\nvalue = [0, 1, 6, 48, 5, 0]'),
#  Text(968.4618395303327, 573.8, 'X[0] <= 7.0\ngini = 0.518\nsamples = 23\nvalue = [0, 1, 5, 15, 2, 0]'),
#  Text(960.6966731898239, 513.4, 'X[2] <= 0.025\ngini = 0.5\nsamples = 6\nvalue = [0, 1, 4, 1, 0, 0]'),
#  Text(956.8140900195694, 453.0, 'X[6] <= 18.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(952.931506849315, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(960.6966731898239, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(964.5792563600783, 453.0, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(976.2270058708415, 513.4, 'X[3] <= 2.475\ngini = 0.304\nsamples = 17\nvalue = [0, 0, 1, 14, 2, 0]'),
#  Text(972.3444227005871, 453.0, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(980.1095890410959, 453.0, 'X[0] <= 10.3\ngini = 0.64\nsamples = 5\nvalue = [0, 0, 1, 2, 2, 0]'),
#  Text(976.2270058708415, 392.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(983.9921722113503, 392.6, 'X[6] <= 24.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(980.1095890410959, 332.19999999999993, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(987.8747553816046, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(1015.0528375733854, 573.8, 'X[6] <= 89.5\ngini = 0.197\nsamples = 37\nvalue = [0, 0, 1, 33, 3, 0]'),
#  Text(1007.2876712328766, 513.4, 'X[6] <= 35.5\ngini = 0.111\nsamples = 34\nvalue = [0, 0, 0, 32, 2, 0]'),
#  Text(1003.4050880626222, 453.0, 'X[5] <= 23.5\ngini = 0.26\nsamples = 13\nvalue = [0, 0, 0, 11, 2, 0]'),
#  Text(999.5225048923678, 392.6, 'X[10] <= 11.75\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 0, 11, 1, 0]'),
#  Text(995.6399217221134, 332.19999999999993, 'X[8] <= 3.38\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(991.757338551859, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(999.5225048923678, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(1003.4050880626222, 332.19999999999993, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(1007.2876712328766, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(1011.170254403131, 453.0, 'gini = 0.0\nsamples = 21\nvalue = [0, 0, 0, 21, 0, 0]'),
#  Text(1022.8180039138942, 513.4, 'X[7] <= 0.993\ngini = 0.667\nsamples = 3\nvalue = [0, 0, 1, 1, 1, 0]'),
#  Text(1018.9354207436398, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(1026.7005870841488, 453.0, 'X[10] <= 12.95\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(1022.8180039138942, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(1030.583170254403, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(999.5225048923678, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(1015.0528375733854, 755.0, 'X[3] <= 2.1\ngini = 0.594\nsamples = 8\nvalue = [0, 0, 0, 3, 4, 1]'),
#  Text(1011.170254403131, 694.6, 'X[5] <= 41.25\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 0, 1]'),
#  Text(1007.2876712328766, 634.2, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(1015.0528375733854, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(1018.9354207436398, 694.6, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(1073.2915851272014, 875.8, 'X[5] <= 18.5\ngini = 0.542\nsamples = 82\nvalue = [0, 0, 2, 23, 50, 7]'),
#  Text(1048.0547945205478, 815.4000000000001, 'X[5] <= 9.5\ngini = 0.465\nsamples = 57\nvalue = [0, 0, 1, 10, 40, 6]'),
#  Text(1034.4657534246576, 755.0, 'X[7] <= 0.995\ngini = 0.623\nsamples = 27\nvalue = [0, 0, 0, 9, 13, 5]'),
#  Text(1026.7005870841488, 694.6, 'X[10] <= 12.95\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 0, 0, 8, 1]'),
#  Text(1022.8180039138942, 634.2, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 0, 8, 0]'),
#  Text(1030.583170254403, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(1042.2309197651664, 694.6, 'X[9] <= 0.695\ngini = 0.623\nsamples = 18\nvalue = [0, 0, 0, 9, 5, 4]'),
#  Text(1038.3483365949119, 634.2, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3]'),
#  Text(1046.1135029354207, 634.2, 'X[4] <= 0.077\ngini = 0.524\nsamples = 15\nvalue = [0, 0, 0, 9, 5, 1]'),
#  Text(1042.2309197651664, 573.8, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(1049.996086105675, 573.8, 'X[9] <= 0.925\ngini = 0.58\nsamples = 10\nvalue = [0, 0, 0, 4, 5, 1]'),
#  Text(1046.1135029354207, 513.4, 'X[4] <= 0.082\ngini = 0.449\nsamples = 7\nvalue = [0, 0, 0, 1, 5, 1]'),
#  Text(1042.2309197651664, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(1049.996086105675, 453.0, 'X[0] <= 12.2\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 1, 5, 0]'),
#  Text(1046.1135029354207, 392.6, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(1053.8786692759295, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(1053.8786692759295, 513.4, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(1061.6438356164383, 755.0, 'X[9] <= 0.695\ngini = 0.187\nsamples = 30\nvalue = [0, 0, 1, 1, 27, 1]'),
#  Text(1057.7612524461838, 694.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(1065.5264187866926, 694.6, 'X[5] <= 14.5\ngini = 0.131\nsamples = 29\nvalue = [0, 0, 0, 1, 27, 1]'),
#  Text(1061.6438356164383, 634.2, 'gini = 0.0\nsamples = 22\nvalue = [0, 0, 0, 0, 22, 0]'),
#  Text(1069.4090019569471, 634.2, 'X[5] <= 15.5\ngini = 0.449\nsamples = 7\nvalue = [0, 0, 0, 1, 5, 1]'),
#  Text(1065.5264187866926, 573.8, 'X[8] <= 3.36\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(1061.6438356164383, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(1069.4090019569471, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(1073.2915851272014, 573.8, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(1098.5283757338552, 815.4000000000001, 'X[8] <= 3.36\ngini = 0.566\nsamples = 25\nvalue = [0, 0, 1, 13, 10, 1]'),
#  Text(1088.821917808219, 755.0, 'X[3] <= 2.15\ngini = 0.439\nsamples = 14\nvalue = [0, 0, 1, 3, 10, 0]'),
#  Text(1081.0567514677102, 694.6, 'X[9] <= 0.77\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 3, 2, 0]'),
#  Text(1077.174168297456, 634.2, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(1084.9393346379647, 634.2, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(1096.5870841487279, 694.6, 'X[3] <= 7.025\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 1, 0, 8, 0]'),
#  Text(1092.7045009784736, 634.2, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 0, 8, 0]'),
#  Text(1100.4696673189824, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(1108.2348336594912, 755.0, 'X[0] <= 5.1\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 0, 10, 0, 1]'),
#  Text(1104.3522504892367, 694.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(1112.1174168297455, 694.6, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]')]

# %%
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df1 = df.head(500)   # in case we use only above 500 data in the dt

# %%
x1 = df1.drop(columns='quality')

# %%
y1 = df1.quality

# %%
dt_model1 = DecisionTreeClassifier()
dt_model1.fit(x1,y1)                    # in case we not split the data into "train" and "test"
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
plt.figure(figsize=(20,20))
tree.plot_tree(dt_model1,filled=True, class_names=[str(i) for i in set(y1)],feature_names=x1.columns)  
# in case as we take small dataset it show welldefine decision tree
# class_names = [str(i) for i set(y1)]-------> print which class it belong
# feature_names --> used to print the col name
# Out:
# [Text(509.16492052023125, 1057.0, 'alcohol <= 9.85\ngini = 0.624\nsamples = 500\nvalue = [1, 16, 239, 184, 52, 8]\nclass = 5'),
#  Text(320.5274566473988, 996.6, 'total_sulfur_dioxide <= 62.5\ngini = 0.504\nsamples = 259\nvalue = [1, 12, 167, 72, 6, 1]\nclass = 5'),
#  Text(200.2456647398844, 936.2, 'citric_acid <= 0.415\ngini = 0.576\nsamples = 169\nvalue = [1, 9, 91, 61, 6, 1]\nclass = 5'),
#  Text(90.84971098265896, 875.8, 'alcohol <= 9.05\ngini = 0.525\nsamples = 131\nvalue = [0, 8, 81, 39, 3, 0]\nclass = 5'),
#  Text(25.803468208092486, 815.4000000000001, 'sulphates <= 0.54\ngini = 0.403\nsamples = 12\nvalue = [0, 2, 1, 9, 0, 0]\nclass = 6'),
#  Text(17.202312138728324, 755.0, 'fixed_acidity <= 7.15\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0, 0, 0]\nclass = 4'),
#  Text(8.601156069364162, 694.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(25.803468208092486, 694.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]\nclass = 4'),
#  Text(34.40462427745665, 755.0, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]\nclass = 6'),
#  Text(155.89595375722544, 815.4000000000001, 'density <= 0.999\ngini = 0.481\nsamples = 119\nvalue = [0, 6, 80, 30, 3, 0]\nclass = 5'),
#  Text(96.76300578034682, 755.0, 'pH <= 3.285\ngini = 0.443\nsamples = 108\nvalue = [0, 5, 77, 23, 3, 0]\nclass = 5'),
#  Text(43.00578034682081, 694.6, 'sulphates <= 0.53\ngini = 0.216\nsamples = 34\nvalue = [0, 2, 30, 1, 1, 0]\nclass = 5'),
#  Text(34.40462427745665, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(51.60693641618497, 634.2, 'citric_acid <= 0.11\ngini = 0.171\nsamples = 33\nvalue = [0, 1, 30, 1, 1, 0]\nclass = 5'),
#  Text(25.803468208092486, 573.8, 'pH <= 3.185\ngini = 0.449\nsamples = 7\nvalue = [0, 1, 5, 1, 0, 0]\nclass = 5'),
#  Text(17.202312138728324, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(34.40462427745665, 513.4, 'citric_acid <= 0.065\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]\nclass = 5'),
#  Text(25.803468208092486, 453.0, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]\nclass = 5'),
#  Text(43.00578034682081, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(77.41040462427746, 573.8, 'chlorides <= 0.067\ngini = 0.074\nsamples = 26\nvalue = [0, 0, 25, 0, 1, 0]\nclass = 5'),
#  Text(68.8092485549133, 513.4, 'chlorides <= 0.065\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 0, 1, 0]\nclass = 5'),
#  Text(60.20809248554913, 453.0, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(77.41040462427746, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(86.01156069364163, 513.4, 'gini = 0.0\nsamples = 22\nvalue = [0, 0, 22, 0, 0, 0]\nclass = 5'),
#  Text(150.52023121387285, 694.6, 'volatile_acidity <= 0.665\ngini = 0.506\nsamples = 74\nvalue = [0, 3, 47, 22, 2, 0]\nclass = 5'),
#  Text(129.01734104046244, 634.2, 'density <= 0.996\ngini = 0.53\nsamples = 52\nvalue = [0, 0, 28, 22, 2, 0]\nclass = 5'),
#  Text(111.81502890173411, 573.8, 'citric_acid <= 0.06\ngini = 0.291\nsamples = 17\nvalue = [0, 0, 14, 3, 0, 0]\nclass = 5'),
#  Text(103.21387283236994, 513.4, 'fixed_acidity <= 6.7\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 2, 3, 0, 0]\nclass = 6'),
#  Text(94.61271676300578, 453.0, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(111.81502890173411, 453.0, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(120.41618497109826, 513.4, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]\nclass = 5'),
#  Text(146.21965317919074, 573.8, 'chlorides <= 0.087\ngini = 0.542\nsamples = 35\nvalue = [0, 0, 14, 19, 2, 0]\nclass = 6'),
#  Text(137.6184971098266, 513.4, 'sulphates <= 0.635\ngini = 0.561\nsamples = 29\nvalue = [0, 0, 14, 13, 2, 0]\nclass = 5'),
#  Text(129.01734104046244, 453.0, 'volatile_acidity <= 0.47\ngini = 0.541\nsamples = 22\nvalue = [0, 0, 7, 13, 2, 0]\nclass = 6'),
#  Text(120.41618497109826, 392.6, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]\nclass = 6'),
#  Text(137.6184971098266, 392.6, 'residual_sugar <= 2.1\ngini = 0.604\nsamples = 15\nvalue = [0, 0, 7, 6, 2, 0]\nclass = 5'),
#  Text(129.01734104046244, 332.19999999999993, 'residual_sugar <= 1.85\ngini = 0.595\nsamples = 11\nvalue = [0, 0, 3, 6, 2, 0]\nclass = 6'),
#  Text(111.81502890173411, 271.79999999999995, 'density <= 0.996\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]\nclass = 5'),
#  Text(103.21387283236994, 211.39999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(120.41618497109826, 211.39999999999998, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(146.21965317919074, 271.79999999999995, 'volatile_acidity <= 0.6\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 0, 5, 2, 0]\nclass = 6'),
#  Text(137.6184971098266, 211.39999999999998, 'free_sulfur_dioxide <= 8.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]\nclass = 7'),
#  Text(129.01734104046244, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(146.21965317919074, 151.0, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(154.82080924855492, 211.39999999999998, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]\nclass = 6'),
#  Text(146.21965317919074, 332.19999999999993, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]\nclass = 5'),
#  Text(146.21965317919074, 453.0, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]\nclass = 5'),
#  Text(154.82080924855492, 513.4, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]\nclass = 6'),
#  Text(172.02312138728325, 634.2, 'sulphates <= 0.485\ngini = 0.236\nsamples = 22\nvalue = [0, 3, 19, 0, 0, 0]\nclass = 5'),
#  Text(163.42196531791907, 573.8, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]\nclass = 4'),
#  Text(180.6242774566474, 573.8, 'citric_acid <= 0.24\ngini = 0.095\nsamples = 20\nvalue = [0, 1, 19, 0, 0, 0]\nclass = 5'),
#  Text(172.02312138728325, 513.4, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 19, 0, 0, 0]\nclass = 5'),
#  Text(189.22543352601156, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(215.02890173410404, 755.0, 'alcohol <= 9.65\ngini = 0.512\nsamples = 11\nvalue = [0, 1, 3, 7, 0, 0]\nclass = 6'),
#  Text(197.82658959537574, 694.6, 'citric_acid <= 0.295\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 1, 7, 0, 0]\nclass = 6'),
#  Text(189.22543352601156, 634.2, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]\nclass = 6'),
#  Text(206.4277456647399, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(232.23121387283237, 694.6, 'total_sulfur_dioxide <= 46.0\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0, 0, 0]\nclass = 5'),
#  Text(223.63005780346822, 634.2, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(240.83236994219652, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(309.64161849710985, 875.8, 'citric_acid <= 0.565\ngini = 0.587\nsamples = 38\nvalue = [1, 1, 10, 22, 3, 1]\nclass = 6'),
#  Text(275.2369942196532, 815.4000000000001, 'fixed_acidity <= 12.35\ngini = 0.438\nsamples = 26\nvalue = [0, 1, 3, 19, 3, 0]\nclass = 6'),
#  Text(258.0346820809249, 755.0, 'sulphates <= 0.52\ngini = 0.245\nsamples = 21\nvalue = [0, 0, 3, 18, 0, 0]\nclass = 6'),
#  Text(249.4335260115607, 694.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(266.63583815028903, 694.6, 'residual_sugar <= 1.65\ngini = 0.18\nsamples = 20\nvalue = [0, 0, 2, 18, 0, 0]\nclass = 6'),
#  Text(258.0346820809249, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(275.2369942196532, 634.2, 'density <= 1.0\ngini = 0.1\nsamples = 19\nvalue = [0, 0, 1, 18, 0, 0]\nclass = 6'),
#  Text(266.63583815028903, 573.8, 'gini = 0.0\nsamples = 18\nvalue = [0, 0, 0, 18, 0, 0]\nclass = 6'),
#  Text(283.83815028901734, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(292.4393063583815, 755.0, 'residual_sugar <= 2.75\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 0, 1, 3, 0]\nclass = 7'),
#  Text(283.83815028901734, 694.6, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]\nclass = 7'),
#  Text(301.0404624277457, 694.6, 'free_sulfur_dioxide <= 21.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]\nclass = 4'),
#  Text(292.4393063583815, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(309.64161849710985, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(344.0462427745665, 815.4000000000001, 'pH <= 3.165\ngini = 0.583\nsamples = 12\nvalue = [1, 0, 7, 3, 0, 1]\nclass = 5'),
#  Text(326.84393063583815, 755.0, 'alcohol <= 9.65\ngini = 0.37\nsamples = 9\nvalue = [0, 0, 7, 1, 0, 1]\nclass = 5'),
#  Text(318.242774566474, 694.6, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]\nclass = 5'),
#  Text(335.4450867052023, 694.6, 'citric_acid <= 0.67\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]\nclass = 6'),
#  Text(326.84393063583815, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(344.0462427745665, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(361.2485549132948, 755.0, 'volatile_acidity <= 0.48\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(352.64739884393066, 694.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(369.84971098265896, 694.6, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]\nclass = 3'),
#  Text(440.8092485549133, 936.2, 'citric_acid <= 0.85\ngini = 0.271\nsamples = 90\nvalue = [0, 3, 76, 11, 0, 0]\nclass = 5'),
#  Text(432.2080924855491, 875.8, 'pH <= 3.335\ngini = 0.255\nsamples = 89\nvalue = [0, 2, 76, 11, 0, 0]\nclass = 5'),
#  Text(395.6531791907515, 815.4000000000001, 'chlorides <= 0.067\ngini = 0.176\nsamples = 73\nvalue = [0, 1, 66, 6, 0, 0]\nclass = 5'),
#  Text(387.05202312138726, 755.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(404.2543352601156, 755.0, 'residual_sugar <= 1.55\ngini = 0.155\nsamples = 72\nvalue = [0, 1, 66, 5, 0, 0]\nclass = 5'),
#  Text(387.05202312138726, 694.6, 'residual_sugar <= 1.45\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]\nclass = 4'),
#  Text(378.4508670520231, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(395.6531791907515, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(421.4566473988439, 694.6, 'density <= 0.996\ngini = 0.133\nsamples = 70\nvalue = [0, 0, 65, 5, 0, 0]\nclass = 5'),
#  Text(412.8554913294798, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(430.0578034682081, 634.2, 'sulphates <= 1.6\ngini = 0.109\nsamples = 69\nvalue = [0, 0, 65, 4, 0, 0]\nclass = 5'),
#  Text(412.8554913294798, 573.8, 'pH <= 3.265\ngini = 0.086\nsamples = 67\nvalue = [0, 0, 64, 3, 0, 0]\nclass = 5'),
#  Text(404.2543352601156, 513.4, 'gini = 0.0\nsamples = 46\nvalue = [0, 0, 46, 0, 0, 0]\nclass = 5'),
#  Text(421.4566473988439, 513.4, 'fixed_acidity <= 10.1\ngini = 0.245\nsamples = 21\nvalue = [0, 0, 18, 3, 0, 0]\nclass = 5'),
#  Text(412.8554913294798, 453.0, 'volatile_acidity <= 0.545\ngini = 0.18\nsamples = 20\nvalue = [0, 0, 18, 2, 0, 0]\nclass = 5'),
#  Text(404.2543352601156, 392.6, 'free_sulfur_dioxide <= 21.5\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]\nclass = 5'),
#  Text(395.6531791907515, 332.19999999999993, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(412.8554913294798, 332.19999999999993, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(421.4566473988439, 392.6, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 15, 0, 0, 0]\nclass = 5'),
#  Text(430.0578034682081, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(447.26011560693644, 573.8, 'total_sulfur_dioxide <= 107.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(438.6589595375723, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(455.8612716763006, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(468.7630057803468, 815.4000000000001, 'citric_acid <= 0.145\ngini = 0.508\nsamples = 16\nvalue = [0, 1, 10, 5, 0, 0]\nclass = 5'),
#  Text(447.26011560693644, 755.0, 'citric_acid <= 0.06\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2, 0, 0]\nclass = 6'),
#  Text(438.6589595375723, 694.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(455.8612716763006, 694.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(490.26589595375725, 755.0, 'fixed_acidity <= 7.9\ngini = 0.355\nsamples = 13\nvalue = [0, 0, 10, 3, 0, 0]\nclass = 5'),
#  Text(473.0635838150289, 694.6, 'pH <= 3.565\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 9, 1, 0, 0]\nclass = 5'),
#  Text(464.46242774566474, 634.2, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]\nclass = 5'),
#  Text(481.66473988439304, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(507.46820809248555, 694.6, 'fixed_acidity <= 9.05\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]\nclass = 6'),
#  Text(498.8670520231214, 634.2, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(516.0693641618498, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(449.4104046242775, 875.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(697.8023843930636, 996.6, 'sulphates <= 0.545\ngini = 0.657\nsamples = 241\nvalue = [0, 4, 72, 112, 46, 7]\nclass = 6'),
#  Text(541.8728323699422, 936.2, 'chlorides <= 0.08\ngini = 0.408\nsamples = 32\nvalue = [0, 2, 24, 5, 1, 0]\nclass = 5'),
#  Text(533.2716763005781, 875.8, 'density <= 0.995\ngini = 0.675\nsamples = 13\nvalue = [0, 2, 5, 5, 1, 0]\nclass = 5'),
#  Text(516.0693641618498, 815.4000000000001, 'residual_sugar <= 1.3\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 0, 1, 0]\nclass = 4'),
#  Text(507.46820809248555, 755.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(524.6705202312139, 755.0, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]\nclass = 4'),
#  Text(550.4739884393064, 815.4000000000001, 'residual_sugar <= 1.85\ngini = 0.5\nsamples = 10\nvalue = [0, 0, 5, 5, 0, 0]\nclass = 5'),
#  Text(541.8728323699422, 755.0, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(559.0751445086705, 755.0, 'fixed_acidity <= 7.5\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 5, 2, 0, 0]\nclass = 5'),
#  Text(550.4739884393064, 694.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(567.6763005780347, 694.6, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]\nclass = 5'),
#  Text(550.4739884393064, 875.8, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 19, 0, 0, 0]\nclass = 5'),
#  Text(853.731936416185, 936.2, 'sulphates <= 0.705\ngini = 0.638\nsamples = 209\nvalue = [0, 2, 48, 107, 45, 7]\nclass = 6'),
#  Text(702.4725433526012, 875.8, 'density <= 1.0\ngini = 0.53\nsamples = 100\nvalue = [0, 2, 23, 64, 8, 3]\nclass = 6'),
#  Text(693.871387283237, 815.4000000000001, 'pH <= 3.485\ngini = 0.513\nsamples = 98\nvalue = [0, 2, 23, 64, 6, 3]\nclass = 6'),
#  Text(615.7890173410404, 755.0, 'pH <= 3.055\ngini = 0.45\nsamples = 83\nvalue = [0, 1, 17, 59, 3, 3]\nclass = 6'),
#  Text(584.878612716763, 694.6, 'sulphates <= 0.63\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]\nclass = 5'),
#  Text(576.2774566473988, 634.2, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(593.4797687861271, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(646.6994219653179, 694.6, 'free_sulfur_dioxide <= 5.5\ngini = 0.427\nsamples = 79\nvalue = [0, 1, 14, 58, 3, 3]\nclass = 6'),
#  Text(610.6820809248555, 634.2, 'density <= 0.998\ngini = 0.656\nsamples = 8\nvalue = [0, 0, 3, 3, 0, 2]\nclass = 5'),
#  Text(602.0809248554914, 573.8, 'alcohol <= 10.9\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 3, 0, 2]\nclass = 6'),
#  Text(593.4797687861271, 513.4, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(610.6820809248555, 513.4, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]\nclass = 8'),
#  Text(619.2832369942197, 573.8, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(682.7167630057803, 634.2, 'pH <= 3.385\ngini = 0.374\nsamples = 71\nvalue = [0, 1, 11, 55, 3, 1]\nclass = 6'),
#  Text(636.485549132948, 573.8, 'residual_sugar <= 4.65\ngini = 0.324\nsamples = 54\nvalue = [0, 1, 5, 44, 3, 1]\nclass = 6'),
#  Text(627.8843930635838, 513.4, 'citric_acid <= 0.035\ngini = 0.298\nsamples = 53\nvalue = [0, 1, 5, 44, 3, 0]\nclass = 6'),
#  Text(619.2832369942197, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(636.485549132948, 453.0, 'density <= 1.0\ngini = 0.274\nsamples = 52\nvalue = [0, 1, 4, 44, 3, 0]\nclass = 6'),
#  Text(595.6300578034682, 392.6, 'citric_acid <= 0.305\ngini = 0.228\nsamples = 48\nvalue = [0, 1, 3, 42, 2, 0]\nclass = 6'),
#  Text(565.5260115606936, 332.19999999999993, 'alcohol <= 10.95\ngini = 0.08\nsamples = 24\nvalue = [0, 0, 1, 23, 0, 0]\nclass = 6'),
#  Text(556.9248554913295, 271.79999999999995, 'gini = 0.0\nsamples = 23\nvalue = [0, 0, 0, 23, 0, 0]\nclass = 6'),
#  Text(574.1271676300578, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(625.7341040462428, 332.19999999999993, 'citric_acid <= 0.37\ngini = 0.358\nsamples = 24\nvalue = [0, 1, 2, 19, 2, 0]\nclass = 6'),
#  Text(591.3294797687861, 271.79999999999995, 'alcohol <= 10.15\ngini = 0.75\nsamples = 4\nvalue = [0, 1, 1, 1, 1, 0]\nclass = 4'),
#  Text(582.7283236994219, 211.39999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(599.9306358381504, 211.39999999999998, 'fixed_acidity <= 8.1\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 1, 1, 0, 0]\nclass = 4'),
#  Text(591.3294797687861, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(608.5317919075145, 151.0, 'citric_acid <= 0.335\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]\nclass = 4'),
#  Text(599.9306358381504, 90.59999999999991, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(617.1329479768787, 90.59999999999991, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(660.1387283236994, 271.79999999999995, 'density <= 0.997\ngini = 0.185\nsamples = 20\nvalue = [0, 0, 1, 18, 1, 0]\nclass = 6'),
#  Text(651.5375722543353, 211.39999999999998, 'fixed_acidity <= 10.8\ngini = 0.449\nsamples = 7\nvalue = [0, 0, 1, 5, 1, 0]\nclass = 6'),
#  Text(642.9364161849711, 151.0, 'sulphates <= 0.645\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 5, 1, 0]\nclass = 6'),
#  Text(634.335260115607, 90.59999999999991, 'pH <= 3.24\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]\nclass = 6'),
#  Text(625.7341040462428, 30.200000000000045, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(642.9364161849711, 30.200000000000045, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(651.5375722543353, 90.59999999999991, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]\nclass = 6'),
#  Text(660.1387283236994, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(668.7398843930636, 211.39999999999998, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 13, 0, 0]\nclass = 6'),
#  Text(677.3410404624277, 392.6, 'pH <= 3.14\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 2, 1, 0]\nclass = 6'),
#  Text(668.7398843930636, 332.19999999999993, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(685.9421965317919, 332.19999999999993, 'pH <= 3.24\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]\nclass = 5'),
#  Text(677.3410404624277, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(694.5433526011561, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(645.0867052023121, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(728.9479768786127, 573.8, 'free_sulfur_dioxide <= 9.5\ngini = 0.457\nsamples = 17\nvalue = [0, 0, 6, 11, 0, 0]\nclass = 6'),
#  Text(720.3468208092486, 513.4, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(737.5491329479769, 513.4, 'total_sulfur_dioxide <= 53.5\ngini = 0.391\nsamples = 15\nvalue = [0, 0, 4, 11, 0, 0]\nclass = 6'),
#  Text(720.3468208092486, 453.0, 'pH <= 3.415\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 1, 10, 0, 0]\nclass = 6'),
#  Text(711.7456647398844, 392.6, 'fixed_acidity <= 7.6\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]\nclass = 6'),
#  Text(703.1445086705203, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(720.3468208092486, 332.19999999999993, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(728.9479768786127, 392.6, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]\nclass = 6'),
#  Text(754.7514450867052, 453.0, 'residual_sugar <= 5.45\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]\nclass = 5'),
#  Text(746.150289017341, 392.6, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(763.3526011560693, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(771.9537572254335, 755.0, 'sulphates <= 0.625\ngini = 0.684\nsamples = 15\nvalue = [0, 1, 6, 5, 3, 0]\nclass = 5'),
#  Text(763.3526011560693, 694.6, 'free_sulfur_dioxide <= 18.0\ngini = 0.568\nsamples = 9\nvalue = [0, 1, 0, 5, 3, 0]\nclass = 6'),
#  Text(754.7514450867052, 634.2, 'chlorides <= 0.056\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 0, 5, 0, 0]\nclass = 6'),
#  Text(746.150289017341, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(763.3526011560693, 573.8, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]\nclass = 6'),
#  Text(771.9537572254335, 634.2, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]\nclass = 7'),
#  Text(780.5549132947978, 694.6, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]\nclass = 5'),
#  Text(711.0736994219653, 815.4000000000001, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(1004.9913294797688, 875.8, 'sulphates <= 0.925\ngini = 0.675\nsamples = 109\nvalue = [0, 0, 25, 43, 37, 4]\nclass = 6'),
#  Text(928.3872832369942, 815.4000000000001, 'total_sulfur_dioxide <= 62.0\ngini = 0.687\nsamples = 88\nvalue = [0, 0, 24, 26, 34, 4]\nclass = 7'),
#  Text(856.8901734104046, 755.0, 'alcohol <= 10.45\ngini = 0.632\nsamples = 62\nvalue = [0, 0, 8, 21, 30, 3]\nclass = 7'),
#  Text(806.3583815028902, 694.6, 'free_sulfur_dioxide <= 10.5\ngini = 0.521\nsamples = 19\nvalue = [0, 0, 2, 12, 5, 0]\nclass = 6'),
#  Text(789.1560693641619, 634.2, 'pH <= 3.23\ngini = 0.531\nsamples = 8\nvalue = [0, 0, 1, 2, 5, 0]\nclass = 7'),
#  Text(780.5549132947978, 573.8, 'sulphates <= 0.86\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 0, 5, 0]\nclass = 7'),
#  Text(771.9537572254335, 513.4, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]\nclass = 7'),
#  Text(789.1560693641619, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(797.7572254335261, 573.8, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(823.5606936416185, 634.2, 'volatile_acidity <= 0.632\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 1, 10, 0, 0]\nclass = 6'),
#  Text(814.9595375722544, 573.8, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]\nclass = 6'),
#  Text(832.1618497109827, 573.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(907.4219653179191, 694.6, 'pH <= 3.33\ngini = 0.594\nsamples = 43\nvalue = [0, 0, 6, 9, 25, 3]\nclass = 7'),
#  Text(879.4682080924856, 634.2, 'citric_acid <= 0.615\ngini = 0.678\nsamples = 30\nvalue = [0, 0, 6, 9, 13, 2]\nclass = 7'),
#  Text(849.364161849711, 573.8, 'volatile_acidity <= 0.415\ngini = 0.711\nsamples = 22\nvalue = [0, 0, 6, 8, 6, 2]\nclass = 6'),
#  Text(814.9595375722544, 513.4, 'total_sulfur_dioxide <= 18.5\ngini = 0.678\nsamples = 11\nvalue = [0, 0, 3, 1, 5, 2]\nclass = 7'),
#  Text(797.7572254335261, 453.0, 'alcohol <= 11.15\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 0, 0, 2]\nclass = 5'),
#  Text(789.1560693641619, 392.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(806.3583815028902, 392.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]\nclass = 8'),
#  Text(832.1618497109827, 453.0, 'density <= 0.999\ngini = 0.449\nsamples = 7\nvalue = [0, 0, 1, 1, 5, 0]\nclass = 7'),
#  Text(823.5606936416185, 392.6, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]\nclass = 7'),
#  Text(840.7630057803468, 392.6, 'fixed_acidity <= 11.75\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(832.1618497109827, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(849.364161849711, 332.19999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(883.7687861271677, 513.4, 'residual_sugar <= 3.05\ngini = 0.512\nsamples = 11\nvalue = [0, 0, 3, 7, 1, 0]\nclass = 6'),
#  Text(866.5664739884393, 453.0, 'pH <= 3.1\ngini = 0.346\nsamples = 9\nvalue = [0, 0, 2, 7, 0, 0]\nclass = 6'),
#  Text(857.9653179190751, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(875.1676300578035, 392.6, 'citric_acid <= 0.355\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 1, 7, 0, 0]\nclass = 6'),
#  Text(866.5664739884393, 332.19999999999993, 'total_sulfur_dioxide <= 15.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(857.9653179190751, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(875.1676300578035, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(883.7687861271677, 332.19999999999993, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]\nclass = 6'),
#  Text(900.971098265896, 453.0, 'alcohol <= 11.85\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]\nclass = 5'),
#  Text(892.3699421965318, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(909.5722543352601, 392.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(909.5722543352601, 573.8, 'total_sulfur_dioxide <= 38.0\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 1, 7, 0]\nclass = 7'),
#  Text(900.971098265896, 513.4, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]\nclass = 7'),
#  Text(918.1734104046243, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(935.3757225433526, 634.2, 'alcohol <= 12.65\ngini = 0.142\nsamples = 13\nvalue = [0, 0, 0, 0, 12, 1]\nclass = 7'),
#  Text(926.7745664739884, 573.8, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 0, 11, 0]\nclass = 7'),
#  Text(943.9768786127167, 573.8, 'citric_acid <= 0.48\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]\nclass = 7'),
#  Text(935.3757225433526, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(952.5780346820809, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(999.8843930635838, 755.0, 'alcohol <= 11.35\ngini = 0.559\nsamples = 26\nvalue = [0, 0, 16, 5, 4, 1]\nclass = 5'),
#  Text(961.179190751445, 694.6, 'chlorides <= 0.078\ngini = 0.29\nsamples = 18\nvalue = [0, 0, 15, 1, 2, 0]\nclass = 5'),
#  Text(952.5780346820809, 634.2, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0, 0]\nclass = 5'),
#  Text(969.7803468208093, 634.2, 'volatile_acidity <= 0.33\ngini = 0.64\nsamples = 5\nvalue = [0, 0, 2, 1, 2, 0]\nclass = 5'),
#  Text(961.179190751445, 573.8, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(978.3815028901735, 573.8, 'total_sulfur_dioxide <= 70.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]\nclass = 5'),
#  Text(969.7803468208093, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(986.9826589595376, 513.4, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(1038.5895953757226, 694.6, 'density <= 1.001\ngini = 0.656\nsamples = 8\nvalue = [0, 0, 1, 4, 2, 1]\nclass = 6'),
#  Text(1029.9884393063585, 634.2, 'free_sulfur_dioxide <= 18.0\ngini = 0.571\nsamples = 7\nvalue = [0, 0, 0, 4, 2, 1]\nclass = 6'),
#  Text(1012.7861271676301, 573.8, 'residual_sugar <= 1.3\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]\nclass = 7'),
#  Text(1004.1849710982659, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(1021.3872832369942, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(1047.1907514450868, 573.8, 'chlorides <= 0.088\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 4, 1, 0]\nclass = 6'),
#  Text(1038.5895953757226, 513.4, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]\nclass = 6'),
#  Text(1055.791907514451, 513.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(1047.1907514450868, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(1081.5953757225434, 815.4000000000001, 'total_sulfur_dioxide <= 18.5\ngini = 0.322\nsamples = 21\nvalue = [0, 0, 1, 17, 3, 0]\nclass = 6'),
#  Text(1064.393063583815, 755.0, 'sulphates <= 1.005\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 3, 0]\nclass = 7'),
#  Text(1055.791907514451, 694.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(1072.9942196531792, 694.6, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]\nclass = 7'),
#  Text(1098.7976878612717, 755.0, 'chlorides <= 0.071\ngini = 0.111\nsamples = 17\nvalue = [0, 0, 1, 16, 0, 0]\nclass = 6'),
#  Text(1090.1965317919075, 694.6, 'free_sulfur_dioxide <= 10.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]\nclass = 6'),
#  Text(1081.5953757225434, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(1098.7976878612717, 634.2, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(1107.3988439306358, 694.6, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]\nclass = 6')]

# %%
plt.figure(figsize=(20,20))
tree.plot_tree(dt_model1,filled=True, class_names=[str(i) for i in set(y1)] ,feature_names=x1.columns)
plt.savefig('dt_model_1')

# plt.savefig("fig_name")   is used to save the fig

# %%
y1
# Out:
# 0      5
# 1      5
# 2      5
# 3      6
# 4      5
#       ..
# 495    8
# 496    6
# 497    5
# 498    8
# 499    6
# Name: quality, Length: 500, dtype: int64

# %%
[str(i) for i in set(y1)]
# Out:
# ['3', '4', '5', '6', '7', '8']

# %%
set(y1)
# Out:
# {3, 4, 5, 6, 7, 8}

# %%
df1
# Out:
#      fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0              7.4              0.70         0.00             1.9      0.076
# 1              7.8              0.88         0.00             2.6      0.098
# 2              7.8              0.76         0.04             2.3      0.092
# 3             11.2              0.28         0.56             1.9      0.075
# 4              7.4              0.70         0.00             1.9      0.076
# ..             ...               ...          ...             ...        ...
# 495           10.7              0.35         0.53             2.6      0.070
# 496            7.8              0.52         0.25             1.9      0.081
# 497            7.2              0.34         0.32             2.5      0.090
# 498           10.7              0.35         0.53             2.6      0.070
# 499            8.7              0.69         0.31             3.0      0.086
#
#      free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                   11.0                  34.0   0.9978  3.51       0.56
# 1                   25.0                  67.0   0.9968  3.20       0.68
# 2                   15.0                  54.0   0.9970  3.26       0.65
# 3                   17.0                  60.0   0.9980  3.16       0.58
# 4                   11.0                  34.0   0.9978  3.51       0.56
# ..                   ...                   ...      ...   ...        ...
# 495                  5.0                  16.0   0.9972  3.15       0.65
# 496                 14.0                  38.0   0.9984  3.43       0.65
# 497                 43.0                 113.0   0.9966  3.32       0.79
# 498                  5.0                  16.0   0.9972  3.15       0.65
# 499                 23.0                  81.0   1.0002  3.48       0.74
#
#      alcohol  quality
# 0        9.4        5
# 1        9.8        5
# 2        9.8        5
# 3        9.8        6
# 4        9.4        5
# ..       ...      ...
# 495     11.0        8
# 496      9.0        6
# 497     11.1        5
# 498     11.0        8
# 499     11.6        6
#
# [500 rows x 12 columns]

# %%
dt_model1.predict(x1)
# Out:
# array([5, 5, 5, 6, 5, 5, 5, 7, 7, 5, 5, 5, 5, 5, 5, 5, 7, 5, 4, 6, 6, 5,
#        5, 5, 6, 5, 5, 5, 5, 6, 5, 6, 5, 6, 5, 6, 6, 7, 4, 5, 5, 4, 6, 5,
#        5, 4, 5, 5, 5, 5, 5, 6, 6, 5, 6, 5, 5, 5, 5, 6, 5, 5, 7, 5, 5, 5,
#        5, 5, 5, 6, 6, 5, 5, 4, 5, 5, 5, 6, 5, 4, 5, 5, 5, 5, 6, 5, 6, 5,
#        5, 5, 5, 6, 5, 5, 4, 6, 5, 5, 5, 6, 6, 6, 6, 5, 5, 5, 5, 5, 6, 5,
#        5, 5, 5, 6, 5, 6, 6, 6, 6, 6, 5, 6, 5, 5, 5, 5, 5, 5, 7, 5, 5, 5,
#        5, 6, 6, 5, 5, 5, 5, 5, 5, 5, 6, 5, 6, 5, 5, 5, 6, 6, 6, 4, 5, 5,
#        5, 5, 5, 5, 5, 6, 5, 4, 6, 5, 5, 5, 5, 4, 6, 5, 4, 6, 6, 6, 5, 5,
#        5, 6, 5, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 6,
#        7, 4, 7, 5, 5, 5, 6, 7, 7, 5, 5, 7, 6, 6, 6, 5, 6, 5, 5, 5, 5, 5,
#        6, 5, 5, 6, 4, 6, 6, 5, 6, 5, 7, 6, 6, 5, 6, 6, 6, 6, 6, 6, 5, 6,
#        6, 7, 7, 6, 5, 5, 6, 6, 6, 6, 5, 5, 6, 5, 5, 5, 5, 7, 5, 4, 5, 5,
#        5, 7, 4, 8, 6, 6, 6, 6, 5, 5, 5, 6, 6, 6, 8, 7, 6, 7, 5, 7, 5, 5,
#        6, 6, 7, 5, 7, 5, 6, 6, 6, 5, 5, 5, 5, 5, 6, 6, 5, 5, 5, 6, 5, 6,
#        6, 6, 6, 6, 6, 5, 5, 6, 5, 6, 7, 6, 7, 5, 5, 6, 6, 6, 7, 5, 6, 5,
#        6, 6, 6, 5, 7, 7, 6, 5, 6, 7, 6, 6, 6, 6, 6, 5, 7, 6, 6, 6, 6, 6,
#        5, 5, 6, 6, 5, 7, 7, 6, 5, 6, 5, 5, 7, 6, 7, 5, 5, 7, 5, 6, 6, 5,
#        6, 7, 6, 7, 6, 6, 6, 6, 6, 6, 5, 6, 6, 6, 6, 7, 8, 6, 5, 5, 5, 7,
#        5, 6, 6, 5, 5, 6, 6, 6, 5, 6, 6, 7, 6, 4, 6, 5, 5, 7, 5, 5, 6, 5,
#        6, 5, 7, 7, 5, 7, 5, 7, 6, 6, 5, 6, 7, 5, 6, 5, 6, 5, 6, 6, 6, 5,
#        8, 6, 7, 7, 7, 6, 5, 5, 6, 6, 6, 6, 6, 7, 5, 8, 5, 5, 7, 3, 6, 5,
#        5, 5, 6, 5, 6, 6, 6, 5, 5, 6, 6, 5, 6, 5, 5, 6, 5, 6, 5, 8, 5, 5,
#        6, 5, 5, 6, 7, 6, 6, 7, 7, 6, 6, 8, 6, 5, 8, 6])

# %%
dt_model1.score(x1,y1)   # as model has 100 percent accuracy as pass whole model
# Out:
# 1.0

# %% [markdown]
# here "less accuracy" is not an issue but there is huge amount of different in train accuracy  and test accuracy  that issue , it always create an issue.
# * here (x1 and y1) -- having the 100% acc and the for random dataset (x_test,y_test)-- 57% only which very very less
# * so model is not acceptable
# * for this we do some sort of prunning operation and built the entire decision tree
# * prunning- try to remove the leaf node [complexity cost became less]

# %%
dt_model1.score(x_test, y_test)  # here we check on random dataset giving 57% accuracy
# in this is kind of overfitted model
# Out:
# 0.5825

# %%
path = dt_model1.cost_complexity_pruning_path(x1,y1)

# %%
path
# Out:
# {'ccp_alphas': array([0.        , 0.00166667, 0.00175   , 0.00181818, 0.00184615,
#         0.00186667, 0.00188235, 0.00192308, 0.002     , 0.002     ,
#         0.002     , 0.002     , 0.002     , 0.002     , 0.002     ,
#         0.002     , 0.002     , 0.002     , 0.002     , 0.00203333,
#         0.00261111, 0.00262769, 0.00266667, 0.00266667, 0.00266667,
#         0.00266667, 0.00266667, 0.00266667, 0.00266667, 0.00266667,
#         0.00271329, 0.00272222, 0.003     , 0.003     , 0.003     ,
#         0.003     , 0.00304762, 0.00305051, 0.00308418, 0.00325   ,
#         0.00328205, 0.00333333, 0.00333333, 0.00334032, 0.00336606,
#         0.00342857, 0.00343316, 0.0035    , 0.0035    , 0.0036    ,
#         0.00363636, 0.00373809, 0.0038    , 0.0038237 , 0.004     ,
#         0.00404444, 0.00428571, 0.00437662, 0.00462338, 0.00465709,
#         0.00466667, 0.0048    , 0.00495726, 0.00504242, 0.00508235,
#         0.00509091, 0.00510606, 0.00516667, 0.00568485, 0.00589394,
#         0.00656364, 0.00671079, 0.0067591 , 0.00688352, 0.00688889,
#         0.007     , 0.00701299, 0.00706234, 0.00725171, 0.00759048,
#         0.00771182, 0.00786235, 0.00813248, 0.00858654, 0.01285167,
#         0.01310242, 0.01335452, 0.01789286, 0.02414791, 0.04600728]),
#  'impurities': array([0.        , 0.00333333, 0.00683333, 0.0104697 , 0.014162  ,
#         0.01789534, 0.02166004, 0.0255062 , 0.0275062 , 0.0295062 ,
#         0.0315062 , 0.0335062 , 0.0355062 , 0.0415062 , 0.0435062 ,
#         0.0455062 , 0.0475062 , 0.0495062 , 0.0515062 , 0.05557286,
#         0.07385064, 0.0869891 , 0.08965577, 0.09232244, 0.0949891 ,
#         0.09765577, 0.10032244, 0.1029891 , 0.10565577, 0.10832244,
#         0.11374901, 0.11647123, 0.11947123, 0.12247123, 0.12547123,
#         0.12847123, 0.13151885, 0.13456936, 0.13765354, 0.14415354,
#         0.15071764, 0.15405097, 0.15738431, 0.16072463, 0.16409069,
#         0.1743764 , 0.17780955, 0.18130955, 0.18480955, 0.18840955,
#         0.19204592, 0.2032602 , 0.2070602 , 0.2185313 , 0.2225313 ,
#         0.22657574, 0.23086146, 0.23523808, 0.23986146, 0.25848983,
#         0.26782316, 0.27262316, 0.28749496, 0.29253738, 0.29761974,
#         0.30271064, 0.3078167 , 0.31298337, 0.31866822, 0.32456216,
#         0.3311258 , 0.33783659, 0.34459569, 0.35147921, 0.3583681 ,
#         0.3653681 , 0.38640708, 0.40053176, 0.40778347, 0.42296443,
#         0.44609989, 0.45396224, 0.46209471, 0.47068125, 0.4963846 ,
#         0.52258943, 0.53594395, 0.55383681, 0.57798472, 0.623992  ])}

# %% [raw]
# path is basically a "dict"-- then suppose to pass a key and then we get a value

# %%
path = dt_model1.cost_complexity_pruning_path(x1,y1)  # original dataset at time of training dataset
ccp_alpha = path.ccp_alphas

# %% [markdown]
# here ccp_alpha is "cost_complexcity of prunning"
# * cc alpha = 0 it mean infinite growing tree it will created branches
# *  * now set some of "cc alpha = thershold -- then at every point it check complexity of each branch and compare it  and stop tree to grow" if value became larger

# %%
ccp_alpha
# Out:
# array([0.        , 0.00166667, 0.00175   , 0.00181818, 0.00184615,
#        0.00186667, 0.00188235, 0.00192308, 0.002     , 0.002     ,
#        0.002     , 0.002     , 0.002     , 0.002     , 0.002     ,
#        0.002     , 0.002     , 0.002     , 0.002     , 0.00203333,
#        0.00261111, 0.00262769, 0.00266667, 0.00266667, 0.00266667,
#        0.00266667, 0.00266667, 0.00266667, 0.00266667, 0.00266667,
#        0.00266667, 0.00271329, 0.00272222, 0.003     , 0.003     ,
#        0.003     , 0.003     , 0.00304762, 0.00304762, 0.00305051,
#        0.00308418, 0.00325   , 0.00328205, 0.00333333, 0.00333333,
#        0.00334032, 0.00336606, 0.00342857, 0.00343316, 0.0035    ,
#        0.0035    , 0.0036    , 0.00363636, 0.00373809, 0.0038    ,
#        0.0038237 , 0.004     , 0.00404444, 0.00428571, 0.00428571,
#        0.00437662, 0.00462338, 0.00465709, 0.00466667, 0.0048    ,
#        0.00487179, 0.00504242, 0.00508235, 0.00509091, 0.00510606,
#        0.00516667, 0.00568485, 0.00589394, 0.00656364, 0.00671079,
#        0.0067591 , 0.00688352, 0.00688889, 0.007     , 0.00701299,
#        0.00706234, 0.00725171, 0.00759048, 0.00771182, 0.00786235,
#        0.00813248, 0.00858654, 0.01285167, 0.01310242, 0.01335452,
#        0.01789286, 0.02414791, 0.04600728])

# %% [markdown]
# * in case passing one by one ccp_alpha[going to each and every value]    and making the decision tree
# *   default ccp_alpha = 0.0
# *  we try to bulid the decison tree with different different type        ccp_alpha value and try to test which going to fine for me

# %%
dt_modle2 = []
for ccp in ccp_alpha:
    dt_m  = DecisionTreeClassifier(ccp_alpha=ccp) 
    dt_m.fit(x1,y1)         
    dt_modle2.append(dt_m)     
    # we try to append our model in this list i having muliple model with different ccp_alpha value

# %%
dt_model2 = []
score = []
for i in ccp_alpha:
    dt_m = DecisionTreeClassifier(ccp_alpha = i)
    dt_m.fit(x1,y1)
    dt_model2.append(dt_m)
    score.append(dt_m.score(x_test, y_test))

    
plt.plot(score, 'r-+')
plt.xlabel('iteration')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %% [raw]
# # prunning
# * chope of the branches
# in case i have taken different different "cost complex value" because each cost complex create the thershold value -- if cost of some branches cost of this more than thershold for this decision tree can not include the branches

# %%
dt_modle2    
# how many model we build all are there with different ccp-alpha value 
# 1st one is defalut ccp_alpha=0.0
# now which i select out of this :- model which having "less overfitted" result one
# Out:
# [DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0016666666666666668, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.00175, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0018181818181818184, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0018461538461538455, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.001866666666666667, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.001882352941176471, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0019230769230769243, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.002, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.002, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.002, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.002, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.002, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.002, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.002, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.002, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.002, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.002, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.002, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.002033333333333334, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0026111111111111114, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0026276923076923083, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0027132867132867106, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.002722222222222221, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.003, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.003, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.003, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.003, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0030476190476190477, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0030476190476190477, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0030505050505050518, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0030841799709724164, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0032500000000000003, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0032820512820512827, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0033333333333333335, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0033333333333333335, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0033403214535289993, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0033660578386605737, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0034285714285714297, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.003433155080213907, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0035, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0035, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0036000000000000008, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.003636363636363637, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0037380946805604365, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.003799999999999999, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.003823698645294892, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.004, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0040444444444444425, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.004285714285714286, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.004285714285714287, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.004376623376623378, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.004623376623376621, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.004657093161377905, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.004666666666666666, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0048, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.004871794871794875, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.005042424242424239, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.005082352941176471, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.005090909090909097, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.005106060606060606, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.005166666666666667, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.005684848484848487, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.005893939393939396, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0065636363636363635, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0067107930828861, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0067591036414565795, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.006883516483516483, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.006888888888888889, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.007000000000000001, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.007012994199018301, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.0070623376623376675, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.007251712992889445, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.00759048284798472, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.007711817594170538, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.007862348178137649, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.008132478632478634, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.008586538461538458, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.012851672777488471, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.013102415587766272, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.013354516483034151, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.01789286463132611, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.024147905954059024, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best'),
#  DecisionTreeClassifier(ccp_alpha=0.04600728380781505, class_weight=None,
#                         criterion='gini', max_depth=None, max_features=None,
#                         max_leaf_nodes=None, min_impurity_decrease=0.0,
#                         min_impurity_split=None, min_samples_leaf=1,
#                         min_samples_split=2, min_weight_fraction_leaf=0.0,
#                         presort='deprecated', random_state=None,
#                         splitter='best')]

# %%
# in above graph we can select the ccp_alpha value where "train and test" accuracy close to each other
# so it not create overfitted model
# 1st i have to find out the trainning accuracy [mode score] one by one we go to each and every model

# %%
train_score = [i.score(x1,y1) for i in dt_modle2]

# %%
test_score = [i.score(x_test ,y_test) for i in dt_modle2]

# %%
# here we plot a graph where we see the sort of relation of train score and test score and ccp_alpha 
# we are suppose to select that model where and train and test score almost closer to each other
fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alpha, train_score, marker='o', label="train",
        drawstyle="steps-post")
ax.plot(ccp_alpha, test_score, marker='o', label="test",
        drawstyle="steps-post")
ax.legend()
plt.show()

# %% [markdown]
# * here we can say that we able to come closer and bring train and test accuracy more near

# %% [markdown]
# * handel the overfitted model just "increase the datasize" because model does not have that kind of relation so just increase the dataset
# * as data size increase the complexcity also increase
# * in case we observe that alpha in b/w 0.1 to 0.4 so model train and test accuracy  both more closer

# %% [raw]
# It is "hyper parameter tunning" try to perform in manually form.
# In case we try to perform with the library called "Random searchCV, GridCV"

# %%
dt_model_ccp = DecisionTreeClassifier(random_state=0 , ccp_alpha=.014) 
# here we tune one perameter ccp_alpha try to perform "prunning"
# we say which branching having complexcity more than this "remove" that branch
dt_model_ccp.fit(x1,y1)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.014, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %%
plt.figure(figsize=(20,20))
tree.plot_tree(dt_model_ccp,filled=True)

# this model is created after performing "hyper parameter tunning"
# Out:
# [Text(558.0, 906.0, 'X[10] <= 9.85\ngini = 0.624\nsamples = 500\nvalue = [1, 16, 239, 184, 52, 8]'),
#  Text(279.0, 543.6, 'X[6] <= 62.5\ngini = 0.504\nsamples = 259\nvalue = [1, 12, 167, 72, 6, 1]'),
#  Text(139.5, 181.19999999999993, 'gini = 0.576\nsamples = 169\nvalue = [1, 9, 91, 61, 6, 1]'),
#  Text(418.5, 181.19999999999993, 'gini = 0.271\nsamples = 90\nvalue = [0, 3, 76, 11, 0, 0]'),
#  Text(837.0, 543.6, 'X[9] <= 0.545\ngini = 0.657\nsamples = 241\nvalue = [0, 4, 72, 112, 46, 7]'),
#  Text(697.5, 181.19999999999993, 'gini = 0.408\nsamples = 32\nvalue = [0, 2, 24, 5, 1, 0]'),
#  Text(976.5, 181.19999999999993, 'gini = 0.638\nsamples = 209\nvalue = [0, 2, 48, 107, 45, 7]')]

# %%
dt_model_ccp.score(x1,y1)
# Out:
# 0.596

# %%
dt_model_ccp.score(x_test,y_test)
# Out:
# 0.5775

# %% [markdown]
# ### Notes:
# * if we getting a good score that not reality if i build a "generalize model" which working in same in both "training and testing unknown dataset" that is called model building
#
# ** if accuracy is very high is not finiallize model it must be constant with both training and testing unknown dataset

# %%
DecisionTreeClassifier()
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [raw]
# In case we use "GridSearchCV" and "RandomSearchCV" for the additional advantage for finding out the "best perameter"
# eg:- 5 set divide (4 set for training and 1 set testing)
#
# Finding out "Best Possible Perameter"
# ** gird_pram make dict--"keys" : values. for spilt the out perameter with best output

# %%
grid_pram = {"criterion":['gini','entropy'],
             "splitter":['best','random'],
             "max_depth" : range(2,40,1),
             "min_samples_split":range(2,10 ,1),
             "min_samples_leaf":range(1,10,1),
             'ccp_alpha':np.random.rand(20)
             }

# it will make all the combination try to all test it

# %%
grid_ccp = GridSearchCV(estimator=dt_model_ccp,param_grid=grid_pram , cv = 10 , n_jobs=-1)
# cv - crossValidation how many dataset it divide
# n_jobs = -1 [[mean occupy all the "processor" of cpu and perform the task]]
# in case of "n_jobs = 4" it mean it not engage all the processor it divide power

# %%
grid_ccp.fit(x1,y1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-115-9256e344b614> in <module>
# ----> 1 grid_ccp.fit(x1,y1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     706                               n_splits, n_candidates, n_candidates * n_splits))
#     707
# --> 708                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     709                                                        X, y,
#     710                                                        train=train, test=test,
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1059
#    1060             with self._backend.retrieval_context():
# -> 1061                 self.retrieve()
#    1062             # Make sure that we get a last message telling us we are done
#    1063             elapsed_time = time.time() - self._start_time
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in retrieve(self)
#     938             try:
#     939                 if getattr(self._backend, 'supports_timeout', False):
# --> 940                     self._output.extend(job.get(timeout=self.timeout))
#     941                 else:
#     942                     self._output.extend(job.get())
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# C:\ProgramData\Anaconda3\lib\concurrent\futures\_base.py in result(self, timeout)
#     432                 return self.__get_result()
#     433
# --> 434             self._condition.wait(timeout)
#     435
#     436             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# C:\ProgramData\Anaconda3\lib\threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
# .best_params_  --> to find out the best perameter from above

grid_ccp.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 17,
#  'min_samples_leaf': 1,
#  'min_samples_split': 3,
#  'splitter': 'random'}

# %%
dt_cpp_new = DecisionTreeClassifier(criterion='entropy' , max_depth=17 ,min_samples_leaf=1 , min_samples_split=3 , splitter='random',ccp_alpha=0.014)

# %%
dt_cpp_new.fit(x1,y1)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.014, criterion='entropy', max_depth=17,
#                        min_samples_split=3, splitter='random')

# %%
dt_cpp_new.score(x1,y1)
# Out:
# 0.636

# %%
dt_cpp_new.score(x_test,y_test)
# Out:
# 0.555

# %%
pred = dt_cpp_new.predict(x_train)

# %%
confusion_matrix(y_train,pred)
# Out:
# array([[  0,   0,   7,   1,   0,   0],
#        [  0,   0,  23,  12,   0,   0],
#        [  3,   0, 389, 120,   0,   0],
#        [  2,   0, 201, 270,   4,   0],
#        [  0,   0,  18, 123,  12,   0],
#        [  0,   0,   1,  13,   0,   0]], dtype=int64)
