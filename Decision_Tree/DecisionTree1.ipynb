# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree 
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.metrics import accuracy_score , confusion_matrix , roc_auc_score, roc_curve
from pandas_profiling import ProfileReport

# %% [markdown]
# The dataset is "quality of wine" having mixture of different component

# %%
df = pd.read_csv("winequality_red.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4        5
# 1               7.8             0.880         0.00  ...       0.68      9.8        5
# 2               7.8             0.760         0.04  ...       0.65      9.8        5
# 3              11.2             0.280         0.56  ...       0.58      9.8        6
# 4               7.4             0.700         0.00  ...       0.56      9.4        5
# ...             ...               ...          ...  ...        ...      ...      ...
# 1594            6.2             0.600         0.08  ...       0.58     10.5        5
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1596            6.3             0.510         0.13  ...       0.75     11.0        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
# ...

# %% [markdown]
# #### Here we build the classifier model where model will able to predict or it will lable each and every wine based on different different reading of attribute

# %%
type("qualilty")  # str type so it is in classification format
df.dtypes
# Out:
# fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
ProfileReport(df)
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %%
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
x = df.drop(columns="quality")

# %%
x
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  ...    pH  sulphates  alcohol
# 0               7.4             0.700         0.00  ...  3.51       0.56      9.4
# 1               7.8             0.880         0.00  ...  3.20       0.68      9.8
# 2               7.8             0.760         0.04  ...  3.26       0.65      9.8
# 3              11.2             0.280         0.56  ...  3.16       0.58      9.8
# 4               7.4             0.700         0.00  ...  3.51       0.56      9.4
# ...             ...               ...          ...  ...   ...        ...      ...
# 1594            6.2             0.600         0.08  ...  3.45       0.58     10.5
# 1595            5.9             0.550         0.10  ...  3.52       0.76     11.2
# 1596            6.3             0.510         0.13  ...  3.42       0.75     11.0
# 1597            5.9             0.645         0.12  ...  3.57       0.71     10.2
# ...

# %%
y = df["quality"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.40, random_state = 500)

# %% [markdown]
# #### Note
# Accuracy is depend on the "random_state" and the "test_size" as we change the input it reflect the accuracy change
#
# * some time duplicate row affect the accuracy
# * during the checking of the score we pass the unknown data set which not pass previously
# * pass the new dataset for the "score" or "accuracy"

# %%
dt_model = DecisionTreeClassifier()

# %%
dt_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
dt_model.predict(x_test)
# Out:
# array([7, 5, 5, 7, 5, 6, 5, 6, 7, 6, 6, 5, 5, 6, 5, 5, 7, 6, 6, 6, 5, 5,
#        6, 6, 6, 5, 7, 6, 7, 5, 5, 6, 6, 5, 5, 6, 6, 8, 5, 6, 6, 7, 5, 6,
#        6, 5, 6, 5, 5, 5, 5, 6, 5, 5, 6, 8, 5, 6, 6, 5, 5, 5, 6, 5, 6, 6,
#        7, 5, 6, 5, 6, 5, 5, 7, 6, 5, 5, 5, 6, 5, 5, 6, 6, 7, 7, 5, 5, 5,
#        7, 6, 6, 5, 7, 5, 6, 6, 7, 6, 6, 6, 5, 6, 6, 5, 4, 7, 5, 5, 6, 6,
#        5, 6, 5, 5, 6, 6, 5, 7, 5, 6, 6, 5, 6, 4, 5, 5, 6, 5, 6, 7, 6, 5,
#        5, 5, 6, 6, 7, 6, 6, 6, 6, 5, 5, 6, 5, 4, 5, 5, 5, 5, 6, 6, 6, 5,
#        5, 6, 5, 7, 6, 4, 6, 5, 5, 6, 6, 7, 6, 6, 7, 6, 5, 5, 6, 5, 6, 5,
#        6, 6, 6, 6, 6, 5, 5, 7, 6, 5, 5, 5, 6, 6, 6, 5, 6, 6, 6, 6, 6, 5,
#        6, 5, 7, 5, 6, 5, 5, 5, 7, 5, 4, 7, 5, 5, 5, 5, 6, 5, 5, 5, 5, 6,
#        6, 5, 6, 6, 7, 6, 5, 6, 5, 6, 5, 7, 6, 7, 7, 6, 5, 7, 6, 5, 6, 6,
#        6, 6, 5, 6, 5, 7, 6, 5, 6, 6, 7, 6, 6, 6, 5, 6, 5, 6, 6, 6, 7, 5,
#        7, 6, 5, 5, 6, 5, 6, 5, 6, 6, 5, 6, 6, 6, 6, 6, 7, 7, 8, 5, 6, 6,
# ...

# %%
dt_model.score(x_test,y_test)  # in case as accuracy is less 57%
# Out:
# 0.5703125

# %% [markdown]
# ## In case change the Perameter --
# criterion = "entropy"    the default in gini one

# %%
dt_en = DecisionTreeClassifier(criterion="entropy")

# %%
dt_en.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
dt_en.score(x_test,y_test)
# Out:
# 0.5640625

# %% [markdown]
# ##### dot file
# let just create "dot file" and then we try to understand what type of data is created in backand and
# * Tree created in backend

# %%
outfile = open("dt_en_meta.dot","w")
tree.export_graphviz(dt_en,out_file=outfile, feature_names=x.columns)

# %%
dir()
# Out:
# ['DecisionTreeClassifier',
#  'GridSearchCV',
#  'In',
#  'Out',
#  'ProfileReport',
#  '_',
#  '_11',
#  '_15',
#  '_16',
#  '_17',
#  '_19',
#  '_22',
#  '_23',
#  '_24',
#  '_25',
#  '_27',
#  '_31',
#  '_32',
#  '_33',
#  '_37',
#  '_38',
#  '_39',
#  '_40',
#  '_42',
#  '_46',
#  '_47',
#  '_48',
#  '_50',
#  '_52',
#  '_53',
#  '_6',
#  '_7',
#  '_8',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i41',
#  '_i42',
#  '_i43',
#  '_i44',
#  '_i45',
#  '_i46',
#  '_i47',
#  '_i48',
#  '_i49',
# ...
