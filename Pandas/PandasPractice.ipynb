# %%
import pandas as pd

# %%
pwd()
# Out:
# '/home/arcgate/Desktop/pcBackup-20220708T072513Z-001/pcBackup/oops/pandas'

# %%
pd=pd.read_csv('/home/arcgate/Desktop/pandas/annual-enterprise-survey-2021-financial-year-provisional-csv.csv')

# %%
pd
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
pd.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 1  2021                     Level 1                99999       All industries
# 2  2021                     Level 1                99999       All industries
# 3  2021                     Level 1                99999       All industries
# 4  2021                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
pd.head(10)
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 1  2021                     Level 1                99999       All industries
# 2  2021                     Level 1                99999       All industries
# 3  2021                     Level 1                99999       All industries
# 4  2021                     Level 1                99999       All industries
# 5  2021                     Level 1                99999       All industries
# 6  2021                     Level 1                99999       All industries
# 7  2021                     Level 1                99999       All industries
# 8  2021                     Level 1                99999       All industries
# 9  2021                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# ...

# %%
type(pd)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.tail()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 41710  Food product manufacturing  Percentage           H37
# 41711  Food product manufacturing  Percentage           H38
# 41712  Food product manufacturing  Percentage           H39
# 41713  Food product manufacturing  Percentage           H40
# 41714  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 41710                          Quick ratio  Financial ratios    52
# 41711  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
import pandas as pd      
# in case pd is  declare inside pd so you need re-insiallize the "import pandas as pd"

# %%
df = pd.read_csv('/home/arcgate/Desktop/pandas/annual-enterprise-survey-2021-financial-year-provisional-csv.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1= df.head()          # in case we want to store the df1 into new csv.file

# %%
df.tail()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 41710  Food product manufacturing  Percentage           H37
# 41711  Food product manufacturing  Percentage           H38
# 41712  Food product manufacturing  Percentage           H39
# 41713  Food product manufacturing  Percentage           H40
# 41714  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 41710                          Quick ratio  Financial ratios    52
# 41711  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
df1.to_csv("test.csv")         # to store the data of df1 into new file"test.csv"

# %%
# !ls
# Out:
#  annual-enterprise-survey-2021-financial-year-provisional-csv.csv
#  PandasPractice.ipynb
#  PandasSession_1-2.ipynb
# 'Pandas session 1.ipynb'
#  test1.csv
#  test.csv

# %%
pd.read_csv("test.csv")
# Out:
#    Unnamed: 0  Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0           0  2021                     Level 1                 99999
# 1           1  2021                     Level 1                 99999
# 2           2  2021                     Level 1                 99999
# 3           3  2021                     Level 1                 99999
# 4           4  2021                     Level 1                 99999
#
#   Industry_name_NZSIOC               Units Variable_code  \
# 0       All industries  Dollars (millions)           H01
# 1       All industries  Dollars (millions)           H04
# 2       All industries  Dollars (millions)           H05
# 3       All industries  Dollars (millions)           H07
# 4       All industries  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# ...

# %%
df = pd.read_csv("annual-enterprise-survey-2021-financial-year-provisional-csv.csv",sep=",")  
#sep="@" in case seperate by @ in 
# csv file ","--> seperate by comma is default

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df2= pd.read_csv("test1.csv",sep="#",skiprows=[1,2,3])   # in case the file has sep with "#

# %% [markdown]
# In case 0 is used to reflect the "column" name and in any case not spikrows the 0

# %%
df2
# Out:
#    Unnamed: 0  Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0           3  2021                     Level 1                 99999
# 1           4  2021                     Level 1                 99999
#
#   Industry_name_NZSIOC               Units Variable_code  \
# 0       All industries  Dollars (millions)           H07
# 1       All industries  Dollars (millions)           H08
#
#           Variable_name      Variable_category    Value  \
# 0  Non-operating income  Financial performance   33#020
# 1     Total expenditure  Financial performance  654#404
#
#                               Industry_code_ANZSIC06
# 0  ANZSIC06 divisions A-S (excluding classes K633...
# 1  ANZSIC06 divisions A-S (excluding classes K633...

# %%
df.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 1  2021                     Level 1                99999       All industries
# 2  2021                     Level 1                99999       All industries
# 3  2021                     Level 1                99999       All industries
# 4  2021                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
df.describe()
# Out:
#               Year
# count  41715.00000
# mean    2017.00000
# std        2.58202
# min     2013.00000
# 25%     2015.00000
# 50%     2017.00000
# 75%     2019.00000
# max     2021.00000

# %% [raw]
# In case describe is used to give only detail for the "numeric value only"  in case "year" has numerical data
#
# # extra detail refer  to the copy notes

# %%
df.dtypes
# Out:
# Year                            int64
# Industry_aggregation_NZSIOC    object
# Industry_code_NZSIOC           object
# Industry_name_NZSIOC           object
# Units                          object
# Variable_code                  object
# Variable_name                  object
# Variable_category              object
# Value                          object
# Industry_code_ANZSIC06         object
# dtype: object

# %% [raw]
# in case datatype show for col value -----> in case int data is only in the "year"

# %%
df5 = pd.read_csv("annual-enterprise-survey-2021-financial-year-provisional-csv.csv",sep=",",header=None)  
df5
# Out:
#           0                            1                     2  \
# 0      Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC
# 1      2021                      Level 1                 99999
# 2      2021                      Level 1                 99999
# 3      2021                      Level 1                 99999
# 4      2021                      Level 1                 99999
# ...     ...                          ...                   ...
# 41711  2013                      Level 3                  ZZ11
# 41712  2013                      Level 3                  ZZ11
# 41713  2013                      Level 3                  ZZ11
# 41714  2013                      Level 3                  ZZ11
# 41715  2013                      Level 3                  ZZ11
#
#                                 3                   4              5  \
# 0            Industry_name_NZSIOC               Units  Variable_code
# ...

# %%
# in case "header" and "names"

df5 = pd.read_csv("annual-enterprise-survey-2021-financial-year-provisional-csv.csv",sep=",",header=None,names=["A","b","c","d","e","r","t","w","h","k","l"])  
df5
# Out:
#           A                            b                     c  \
# 0      Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC
# 1      2021                      Level 1                 99999
# 2      2021                      Level 1                 99999
# 3      2021                      Level 1                 99999
# 4      2021                      Level 1                 99999
# ...     ...                          ...                   ...
# 41711  2013                      Level 3                  ZZ11
# 41712  2013                      Level 3                  ZZ11
# 41713  2013                      Level 3                  ZZ11
# 41714  2013                      Level 3                  ZZ11
# 41715  2013                      Level 3                  ZZ11
#
#                                 d                   e              r  \
# 0            Industry_name_NZSIOC               Units  Variable_code
# ...

# %%
# in case "na_values" is created

df6= pd.read_csv("annual-enterprise-survey-2021-financial-year-provisional-csv.csv",na_values=["99999","Level 2","H04"]) 
df6
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                  NaN
# 1      2021                     Level 1                  NaN
# 2      2021                     Level 1                  NaN
# 3      2021                     Level 1                  NaN
# 4      2021                     Level 1                  NaN
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
df1.to_csv("Result2.csv",sep=",",columns=["Year","Units","Value"])

# %%
df =pd.read_csv("Result2.csv")

# %%
df
# Out:
#    Unnamed: 0  Year               Units    Value
# 0           0  2021  Dollars (millions)  757,504
# 1           1  2021  Dollars (millions)  674,890
# 2           2  2021  Dollars (millions)   49,593
# 3           3  2021  Dollars (millions)   33,020
# 4           4  2021  Dollars (millions)  654,404

# %% [markdown]
# In case extra index value is added

# %% [raw]
# Inr case to remove the extra index  then at saving time use ----"index=False"

# %%
df1.to_csv("Result3.csv",sep=",",columns=["Year","Units","Value"],index=False)

# %%
df =pd.read_csv("Result3.csv")

# %%
df
# Out:
#    Year               Units    Value
# 0  2021  Dollars (millions)  757,504
# 1  2021  Dollars (millions)  674,890
# 2  2021  Dollars (millions)   49,593
# 3  2021  Dollars (millions)   33,020
# 4  2021  Dollars (millions)  654,404

# %%
df.columns           # give the col
# Out:
# Index(['Year', 'Units', 'Value'], dtype='object')

# %% [raw]
# 2 type of data type:--- "series" and "dataframe"
#
# series-- single col. data
# dataframe-- more than single col. data

# %%
type(df["Year"])
# Out:
# pandas.core.series.Series

# %%
type(df[["Year","Value"]])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[["Year"]])           # [[]] used as dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
df[["Year","Value"]]
# Out:
#    Year    Value
# 0  2021  757,504
# 1  2021  674,890
# 2  2021   49,593
# 3  2021   33,020
# 4  2021  654,404

# %%
df["Year"]     # data in series format
# Out:
# 0    2021
# 1    2021
# 2    2021
# 3    2021
# 4    2021
# Name: Year, dtype: int64

# %%
df[["Year"]]      # data in dataframe format
# Out:
#    Year
# 0  2021
# 1  2021
# 2  2021
# 3  2021
# 4  2021

# %% [raw]
# In case we load the data of excel sheet and sheet name is "Phone_Numbers"

# %%
df2 = pd.read_excel("Book3.xlsx",sheet_name="Phone_Numbers")

# %%
df2
# Out:
#      omrrts Phone_Number
# 0     10001     555-1234
# 1     10002     555-1236
# 2     10003     555-1238
# 3     10004     555-1240
# 4     10005     555-1242
# ..      ...          ...
# 141   10146     555-1526
# 142   10147     555-1528
# 143   10148     555-1530
# 144   10149     555-1532
# 145   10150     555-1534
#
# [146 rows x 2 columns]

# %% [raw]
# Now we can load the data from the html sheet

# %%
df3= pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")

# %%
df3
# Out:
# [       Season   Age                                     Tm  \
#  0     2008-09  19.0  Did Not Play (other pro league—Spain)
#  1     2009-10  20.0                                    OKC
#  2     2010-11  21.0                                    OKC
#  3     2011-12  22.0                                    OKC
#  4     2012-13  23.0                                    OKC
#  5     2013-14  24.0                                    OKC
#  6     2014-15  25.0                                    OKC
#  7     2015-16  26.0                                    OKC
#  8     2016-17  27.0                                    TOT
#  9     2016-17  27.0                                    ORL
#  10    2016-17  27.0                                    TOR
#  11    2017-18  28.0                                    TOR
#  12    2018-19  29.0                                    TOR
#  13    2019-20  30.0                                    TOR
#  14    2020-21  31.0                                    LAC
# ...

# %%
type(df3)
# Out:
# list

# %%
len(df3)       # in case there is total 6 no. of table
# Out:
# 6

# %%
df3[0]
# Out:
#        Season   Age                                     Tm  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...

# %%
df3[6]   # total 6 no. of table occurs
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-1b520c69af1a> in <module>
# ----> 1 df3[6]   # total 6 no. of table occurs
#
# IndexError: list index out of range

# %%
# df3[[5]]   ---->list indices must be integers or slices, not list
df3[5]
# Out:
#        Season   Age   Tm   Lg  Pos      G      MP   PER    TS%   3PAr  ...  \
# 0     2009-10  20.0  OKC  NBA   PF    6.0   153.0  15.3  0.596  0.000  ...
# 1     2010-11  21.0  OKC  NBA   PF   17.0   490.0  15.2  0.514  0.007  ...
# 2     2011-12  22.0  OKC  NBA   PF   20.0   569.0  18.9  0.558  0.025  ...
# 3     2012-13  23.0  OKC  NBA   PF   11.0   366.0  17.1  0.484  0.067  ...
# 4     2013-14  24.0  OKC  NBA   PF   17.0   581.0  16.6  0.633  0.088  ...
# 5     2015-16  26.0  OKC  NBA   PF   18.0   602.0  15.3  0.629  0.423  ...
# 6     2016-17  27.0  TOR  NBA   PF   10.0   307.0  14.4  0.527  0.292  ...
# 7     2017-18  28.0  TOR  NBA   PF   10.0   260.0  10.9  0.533  0.333  ...
# 8     2018-19  29.0  TOR  NBA    C   24.0   500.0  15.1  0.532  0.197  ...
# 9     2019-20  30.0  TOR  NBA    C   11.0   251.0  25.2  0.702  0.409  ...
# 10    2020-21  31.0  LAC  NBA    C    2.0    18.0  30.7  0.644  0.333  ...
# ...

# %%
# now convert the 5no. table into the csv format

# %%
df3[4].to_csv("html_5NoTable")

# %% [raw]
# now save all the table in csv format with different file

# %%
html_data = pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")
for i in range(len(html_data)):
    html_data[i].to_csv(f"html_data{i}.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#
# ~/anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# ~/anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#
# ...

# %%
# calling the data using the link---- where the data is store in the row form

pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [raw]
# Creating the Small Dataset

# %%
a = """{
"name" : "ashish",
"phone_no" : 7788994455,
"comp_invest" : ["Arcgate","Deloitte","wipro","tcs","amazon","flipkat","verizon"]
}
"""

# %%
# now load the data into json

# %%
import json

# %%
a1 = json.loads(a)

# %%
a1
# Out:
# {'name': 'ashish',
#  'phone_no': 7788994455,
#  'comp_invest': ['Arcgate',
#   'Deloitte',
#   'wipro',
#   'tcs',
#   'amazon',
#   'flipkat',
#   'verizon']}

# %%
pd.DataFrame(a1)
# Out:
#      name    phone_no comp_invest
# 0  ashish  7788994455     Arcgate
# 1  ashish  7788994455    Deloitte
# 2  ashish  7788994455       wipro
# 3  ashish  7788994455         tcs
# 4  ashish  7788994455      amazon
# 5  ashish  7788994455     flipkat
# 6  ashish  7788994455     verizon

# %%
pd.DataFrame(a1, columns=["comp_invest"])
# Out:
#   comp_invest
# 0     Arcgate
# 1    Deloitte
# 2       wipro
# 3         tcs
# 4      amazon
# 5     flipkat
# 6     verizon

# %% [raw]
# In case we import the large data json data------>list ke inside dict

# %%
import requests

# %%
res = requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
res                      # adding the response
# Out:
# <Response [200]>

# %%
js = res.json()

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47610',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47610/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47610/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47610/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47610',
#   'id': 1295757814,
#   'node_id': 'I_kwDOAA0YD85NO7H2',
#   'number': 47610,
#   'title': 'BUG: Pandas refuses to convert object type to string',
#   'user': {'login': 'steve-solun',
#    'id': 108329117,
#    'node_id': 'U_kgDOBnT4nQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/108329117?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/steve-solun',
#    'html_url': 'https://github.com/steve-solun',
# ...

# %%
js[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47610',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47610/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47610/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47610/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/issues/47610',
#  'id': 1295757814,
#  'node_id': 'I_kwDOAA0YD85NO7H2',
#  'number': 47610,
#  'title': 'BUG: Pandas refuses to convert object type to string',
#  'user': {'login': 'steve-solun',
#   'id': 108329117,
#   'node_id': 'U_kgDOBnT4nQ',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/108329117?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/steve-solun',
#   'html_url': 'https://github.com/steve-solun',
#   'followers_url': 'https://api.github.com/users/steve-solun/followers',
# ...

# %%
js[0]["user"]
# Out:
# {'login': 'steve-solun',
#  'id': 108329117,
#  'node_id': 'U_kgDOBnT4nQ',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/108329117?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/steve-solun',
#  'html_url': 'https://github.com/steve-solun',
#  'followers_url': 'https://api.github.com/users/steve-solun/followers',
#  'following_url': 'https://api.github.com/users/steve-solun/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/steve-solun/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/steve-solun/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/steve-solun/subscriptions',
#  'organizations_url': 'https://api.github.com/users/steve-solun/orgs',
#  'repos_url': 'https://api.github.com/users/steve-solun/repos',
#  'events_url': 'https://api.github.com/users/steve-solun/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/steve-solun/received_events',
# ...

# %%
js[0]["title"]
# Out:
# 'BUG: Pandas refuses to convert object type to string'

# %%
# now taking title from each of the dict

for i in range(len(js)):
    print(js[i]["title"])
# Out:
# BUG: Pandas refuses to convert object type to string
# DOC: fix shared compression_options and decompression_options
# BUG: inconsistent index between plain DataFrame and read_sql DataFrame
# BUG: MultiIndex level not sorted (as desired) after making it a CategoricalIndex
# DOC: sample codes should not override Python built-in functions
# BUG: df.groupby().resample()[[cols]] without key columns raise KeyError
# ENH: Display DataFrame column dtypes (data types) for each variable name when printing
# Unique test
# BUG: Make xticks from _quarterly_finder() line up better
# ENH/TST: Add TestBaseReshaping tests for ArrowExtensionArray
# CI: run flake8-pyi with all the other flake8 plugins
# BUG: `pd.period_range` ignores multiple of `start` frequency.
# Added improvements in to_datetime Error reporting message
# BUG: Inconsistent handling of dropping levels in MultiIndex when using IndexSlice
# QST: pd.read_sql how to process with null char '\0'
# ...

# %%
len(js)
# Out:
# 30

# %% [raw]
# Now convert entire data set into the "dataframe"

# %%
pd.DataFrame(js).head()      
## its show that data you store has dict inside dict and many more data in form of ....... show
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
df4 = pd.DataFrame(js)

# %%
js[0]["user"]
# Out:
# {'login': 'steve-solun',
#  'id': 108329117,
#  'node_id': 'U_kgDOBnT4nQ',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/108329117?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/steve-solun',
#  'html_url': 'https://github.com/steve-solun',
#  'followers_url': 'https://api.github.com/users/steve-solun/followers',
#  'following_url': 'https://api.github.com/users/steve-solun/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/steve-solun/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/steve-solun/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/steve-solun/subscriptions',
#  'organizations_url': 'https://api.github.com/users/steve-solun/orgs',
#  'repos_url': 'https://api.github.com/users/steve-solun/repos',
#  'events_url': 'https://api.github.com/users/steve-solun/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/steve-solun/received_events',
# ...

# %%
df4.to_csv("json_dump.csv")

# %% [raw]
# Convert user--> into dataframe format
#
# this are the sol. to store the data "user" in the tabular format

# %%
lis = []            # creating the empty dict
for i in range(len(js)):
    lis.append(js[i]["user"])
pd.DataFrame(lis)
# Out:
#                   login         id               node_id  \
# 0           steve-solun  108329117          U_kgDOBnT4nQ
# 1              alastair      19217      MDQ6VXNlcjE5MjE3
# 2                   jf2   13077143  MDQ6VXNlcjEzMDc3MTQz
# 3                d-s-dc   68206552  MDQ6VXNlcjY4MjA2NTUy
# 4               wany-oh   98004396          U_kgDOBddtrA
# 5               GYHHAHA   41546976  MDQ6VXNlcjQxNTQ2OTc2
# 6              coatless     833642  MDQ6VXNlcjgzMzY0Mg==
# 7              srotondo   97266896          U_kgDOBcws0A
# 8            elidourado      68493      MDQ6VXNlcjY4NDkz
# 9             mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 10           twoertwein    6618166  MDQ6VXNlcjY2MTgxNjY=
# 11               jaheba     133732  MDQ6VXNlcjEzMzczMg==
# 12             dannyi96   15380498  MDQ6VXNlcjE1MzgwNDk4
# 13             mousey92   26246536  MDQ6VXNlcjI2MjQ2NTM2
# 14            flyly0755   45039060  MDQ6VXNlcjQ1MDM5MDYw
# ...

# %%
# 2) all process in single program

user = []
res= requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")
js=res.json()
for i in range(len(js)):
    user.append(js[i]["user"])
    
pd.DataFrame(user)
# Out:
#                   login        id               node_id  \
# 0              alastair     19217      MDQ6VXNlcjE5MjE3
# 1                   jf2  13077143  MDQ6VXNlcjEzMDc3MTQz
# 2                d-s-dc  68206552  MDQ6VXNlcjY4MjA2NTUy
# 3               wany-oh  98004396          U_kgDOBddtrA
# 4               GYHHAHA  41546976  MDQ6VXNlcjQxNTQ2OTc2
# 5              coatless    833642  MDQ6VXNlcjgzMzY0Mg==
# 6              srotondo  97266896          U_kgDOBcws0A
# 7            elidourado     68493      MDQ6VXNlcjY4NDkz
# 8             mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 9            twoertwein   6618166  MDQ6VXNlcjY2MTgxNjY=
# 10               jaheba    133732  MDQ6VXNlcjEzMzczMg==
# 11             dannyi96  15380498  MDQ6VXNlcjE1MzgwNDk4
# 12             mousey92  26246536  MDQ6VXNlcjI2MjQ2NTM2
# 13            flyly0755  45039060  MDQ6VXNlcjQ1MDM5MDYw
# 14               igonro   6860957  MDQ6VXNlcjY4NjA5NTc=
# 15           twoertwein   6618166  MDQ6VXNlcjY2MTgxNjY=
# ...

# %%
# 3) 
pd.DataFrame([js[i]["user"] for i in range(len(js))])
# Out:
#                   login        id               node_id  \
# 0              alastair     19217      MDQ6VXNlcjE5MjE3
# 1                   jf2  13077143  MDQ6VXNlcjEzMDc3MTQz
# 2                d-s-dc  68206552  MDQ6VXNlcjY4MjA2NTUy
# 3               wany-oh  98004396          U_kgDOBddtrA
# 4               GYHHAHA  41546976  MDQ6VXNlcjQxNTQ2OTc2
# 5              coatless    833642  MDQ6VXNlcjgzMzY0Mg==
# 6              srotondo  97266896          U_kgDOBcws0A
# 7            elidourado     68493      MDQ6VXNlcjY4NDkz
# 8             mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 9            twoertwein   6618166  MDQ6VXNlcjY2MTgxNjY=
# 10               jaheba    133732  MDQ6VXNlcjEzMzczMg==
# 11             dannyi96  15380498  MDQ6VXNlcjE1MzgwNDk4
# 12             mousey92  26246536  MDQ6VXNlcjI2MjQ2NTM2
# 13            flyly0755  45039060  MDQ6VXNlcjQ1MDM5MDYw
# 14               igonro   6860957  MDQ6VXNlcjY4NjA5NTc=
# 15           twoertwein   6618166  MDQ6VXNlcjY2MTgxNjY=
# ...

# %%
# 4)
json_data = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")   #pd.read_json in case this function read and load both the json data
data = pd.DataFrame.from_records(json_data['user'])
data.head()
# Out:
#       login        id               node_id  \
# 0  alastair     19217      MDQ6VXNlcjE5MjE3
# 1       jf2  13077143  MDQ6VXNlcjEzMDc3MTQz
# 2    d-s-dc  68206552  MDQ6VXNlcjY4MjA2NTUy
# 3   wany-oh  98004396          U_kgDOBddtrA
# 4   GYHHAHA  41546976  MDQ6VXNlcjQxNTQ2OTc2
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/19217?v=4
# 1  https://avatars.githubusercontent.com/u/130771...
# 2  https://avatars.githubusercontent.com/u/682065...
# 3  https://avatars.githubusercontent.com/u/980043...
# 4  https://avatars.githubusercontent.com/u/415469...
#
#                                      url                     html_url  \
# 0  https://api.github.com/users/alastair  https://github.com/alastair
# 1       https://api.github.com/users/jf2       https://github.com/jf2
# 2    https://api.github.com/users/d-s-dc    https://github.com/d-s-dc
# 3   https://api.github.com/users/wany-oh   https://github.com/wany-oh
# ...

# %%
import pandas as pd

# %%
from_file = pd.read_csv("html_data1.csv")

# %% [markdown]
# # Pickle Format
#
# DataFrame.to_pickle(self,path,compression="infer",protocol=4)
#
# * "infer" from file extension
# * "protocol" -- default --higher --4

# %%
from_file.to_pickle("my_pickle")

# %%
pwd()
# Out:
# '/home/arcgate/Desktop/pandas'

# %%
from_file
# Out:
#        Season   Age   Tm   Lg  Pos      G     GS    MP   FG   FGA  ...    FT%  \
# 0     2009-10  20.0  OKC  NBA   PF    6.0    0.0  25.5  3.3   5.8  ...  0.700
# 1     2010-11  21.0  OKC  NBA   PF   17.0   17.0  28.8  3.9   8.5  ...  0.825
# 2     2011-12  22.0  OKC  NBA   PF   20.0   20.0  28.5  4.2   8.0  ...  0.722
# 3     2012-13  23.0  OKC  NBA   PF   11.0   11.0  33.3  5.4  12.3  ...  0.792
# 4     2013-14  24.0  OKC  NBA   PF   17.0   17.0  34.2  5.1   8.6  ...  0.765
# 5     2015-16  26.0  OKC  NBA   PF   18.0   18.0  33.4  4.7   9.1  ...  0.750
# 6     2016-17  27.0  TOR  NBA   PF   10.0   10.0  30.7  6.0  13.0  ...  0.846
# 7     2017-18  28.0  TOR  NBA   PF   10.0    9.0  26.0  3.0   7.2  ...  0.818
# 8     2018-19  29.0  TOR  NBA    C   24.0    0.0  20.8  3.8   8.0  ...  0.762
# 9     2019-20  30.0  TOR  NBA    C   11.0    0.0  22.8  5.7  10.0  ...  1.000
# 10    2020-21  31.0  LAC  NBA    C    2.0    0.0   9.0  1.5   3.0  ...  1.000
# ...

# %% [markdown]
# # HDF5
# HDFStore(path,mode)
#
# * mode-- default append "a"

# %%
h5_data = pd.HDFStore("tst.h5")

# %%
h5_data["obj1"] = from_file      # store the single column store--- from_file(all data)
# Out:
# /home/arcgate/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3331: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['Season', 'Tm', 'Lg', 'Pos'], dtype='object')]
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
h5_data["obj1"]
# Out:
#        Season   Age   Tm   Lg  Pos      G     GS    MP   FG   FGA  ...    FT%  \
# 0     2009-10  20.0  OKC  NBA   PF    6.0    0.0  25.5  3.3   5.8  ...  0.700
# 1     2010-11  21.0  OKC  NBA   PF   17.0   17.0  28.8  3.9   8.5  ...  0.825
# 2     2011-12  22.0  OKC  NBA   PF   20.0   20.0  28.5  4.2   8.0  ...  0.722
# 3     2012-13  23.0  OKC  NBA   PF   11.0   11.0  33.3  5.4  12.3  ...  0.792
# 4     2013-14  24.0  OKC  NBA   PF   17.0   17.0  34.2  5.1   8.6  ...  0.765
# 5     2015-16  26.0  OKC  NBA   PF   18.0   18.0  33.4  4.7   9.1  ...  0.750
# 6     2016-17  27.0  TOR  NBA   PF   10.0   10.0  30.7  6.0  13.0  ...  0.846
# 7     2017-18  28.0  TOR  NBA   PF   10.0    9.0  26.0  3.0   7.2  ...  0.818
# 8     2018-19  29.0  TOR  NBA    C   24.0    0.0  20.8  3.8   8.0  ...  0.762
# 9     2019-20  30.0  TOR  NBA    C   11.0    0.0  22.8  5.7  10.0  ...  1.000
# 10    2020-21  31.0  LAC  NBA    C    2.0    0.0   9.0  1.5   3.0  ...  1.000
# ...

# %%
h5_data.put("obj2", from_file, format="table")

# %%
h5_data.select("obj2", where =['index >=10 and index <=20'] )
# Out:
#        Season   Age   Tm   Lg  Pos      G     GS    MP   FG  FGA  ...    FT%  \
# 10    2020-21  31.0  LAC  NBA    C    2.0    0.0   9.0  1.5  3.0  ...  1.000
# 11    2021-22  32.0  MIL  NBA   PF    6.0    0.0   3.7  0.7  2.7  ...  0.500
# 12     Career   NaN  NaN  NBA  NaN  152.0  102.0  27.1  4.3  8.6  ...  0.789
# 13        NaN   NaN  NaN  NaN  NaN    NaN    NaN   NaN  NaN  NaN  ...    NaN
# 14  6 seasons   NaN  OKC  NBA  NaN   89.0   83.0  31.0  4.5  8.8  ...  0.768
# 15  4 seasons   NaN  TOR  NBA  NaN   55.0   19.0  24.0  4.5  9.2  ...  0.824
# 16   1 season   NaN  MIL  NBA  NaN    6.0    0.0   3.7  0.7  2.7  ...  0.500
# 17   1 season   NaN  LAC  NBA  NaN    2.0    0.0   9.0  1.5  3.0  ...  1.000
#
#     ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 10  0.5  1.5  2.0  1.0  0.5  1.5  0.5  0.5   5.0
# 11  0.3  1.3  1.7  0.0  0.0  0.0  0.3  0.2   1.5
# 12  1.8  4.5  6.3  0.7  0.4  1.9  0.9  3.0  10.6
# 13  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes[df.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes=="object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes=="object"].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df[["Name"]]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %%
df["Name"][5]
# Out:
# 'Moran, Mr. James'

# %%
df["Name"][5:10]       # series
# Out:
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
df[["Ticket"]][5:10]          # dataframe format
# Out:
#    Ticket
# 5  330877
# 6   17463
# 7  349909
# 8  347742
# 9  237736

# %%
df[["Age","Fare"]]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # sorted format

# %%
sorted(df["Ticket"])
# Out:
# ['110152',
#  '110152',
#  '110152',
#  '110413',
#  '110413',
#  '110413',
#  '110465',
#  '110465',
#  '110564',
#  '110813',
#  '111240',
#  '111320',
#  '111361',
#  '111361',
#  '111369',
#  '111426',
#  '111427',
#  '111428',
#  '112050',
#  '112052',
#  '112053',
#  '112058',
#  '112059',
#  '112277',
#  '112379',
#  '113028',
#  '113043',
#  '113050',
#  '113051',
#  '113055',
#  '113056',
#  '113059',
#  '113501',
#  '113503',
#  '113505',
#  '113505',
#  '113509',
#  '113510',
#  '113514',
#  '113572',
#  '113572',
#  '113760',
#  '113760',
#  '113760',
#  '113760',
#  '113767',
#  '113773',
#  '113776',
#  '113776',
#  '113781',
#  '113781',
#  '113781',
#  '113781',
#  '113783',
#  '113784',
#  '113786',
#  '113787',
#  '113788',
#  '113789',
#  '113789',
#  '113792',
#  '113794',
#  '113796',
#  '113798',
#  '113798',
#  '113800',
#  '113803',
#  '113803',
#  '113804',
#  '113806',
#  '113806',
#  '113807',
#  '11668',
#  '11668',
#  '11751',
#  '11751',
#  '11752',
# ...

# %%
for i in df.columns :
    print(df[[i]])
# Out:
#      PassengerId
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ..           ...
# 886          887
# 887          888
# 888          889
# 889          890
# 890          891
#
# [891 rows x 1 columns]
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]
#      Pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Adding a new column

# %%
df["ashish"] = "singh"

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# dump the data

# %%
df["ashish"]= df["Ticket"]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# in case data of ticket col is copy to ashish

# %%
# data is overwritten
df["ashish"]=df["Fare"]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Catogorical value
#
# data divide into graph

# %%
pd.Categorical(df["Sex"])
# Out:
# [male, female, female, female, male, ..., male, female, female, male, male]
# Length: 891
# Categories (2, object): [female, male]

# %%
pd.Categorical(df["Pclass"])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
# unique element
df["Pclass"].unique()
# Out:
# array([3, 1, 2])

# %% [raw]
# To find "null value in columns"

# %%
df["Cabin"].isnull()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
df["Cabin"][df["Cabin"].isnull()==True]
# Out:
# 0      NaN
# 2      NaN
# 4      NaN
# 5      NaN
# 7      NaN
#       ...
# 884    NaN
# 885    NaN
# 886    NaN
# 888    NaN
# 890    NaN
# Name: Cabin, Length: 687, dtype: object

# %%
ser = df["Cabin"][df["Cabin"].isnull()==True]

# %%
len(ser.index)
# Out:
# 687

# %%
[ser.index]
# Out:
# [Int64Index([  0,   2,   4,   5,   7,   8,   9,  12,  13,  14,
#              ...
#              878, 880, 881, 882, 883, 884, 885, 886, 888, 890],
#             dtype='int64', length=687)]

# %%
df.iloc[ser.index]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df[df['Fare'] == max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df['new_col'] = df['PassengerId']  + df['Age']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv
# Out:
#   File "<ipython-input-162-116c4a29dd0f>", line 1
#     https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv
#            ^
# SyntaxError: invalid syntax

# %%
https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt

# %%
https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv

# %%
https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv

# %%
https://drive.google.com/file/d/1etGP85wJWsgqbsh3gX5oxc8dPKLMA1eT/view
